# %% [markdown]
# # Part I : Data Collection - REE API

# %% [markdown]
# The objective of this session is to understand how data can be retrieved from specific sources as REE API.
#
# To do so, we will use `requests` library and `json` libraries for Python. These libraries are very famous and common python libraries to deal with http request and json file serialization.
#
# Later on, we will use specific libraries for plotting as `matplotlib` and `datetime`.

# %%
# import requests library
import requests
import json
# import plotting library
import matplotlib
import matplotlib.pyplot as plt
from datetime import date, datetime, timedelta

# %% [markdown]
# ### Create the request

# %% [markdown]
# As we have seen before, when we work with APIs, we have to know and hold the URL of the exposed **endpoint** of the server where the information we want is stored. We have to start writing the whole http request to be made. Following concepts explained in class, this will include: an http method, the desired endpoint, headers and parameters.
# Reading the available API documentation (mandatory) available here https://www.ree.es/es/apidatos you can understand that only GET request can be done.
#
# Let's therefore write in our script the desired headers/parameters.
# We need to write also the folder/section we want to access. Note that we can have the same endpoint but different sections from where to get the information.
#
# Most of the times, we need to add some headers to our requests that are required to get the information. The most important one is the **Authorization**, which corresponds to our ID to access that API.
#
# The following code is created only to facilitate the process of the API request generation. Endpoints, archives and headers are always provided in the API documentation, which have to be read.

# %%
endpoint = 'https://apidatos.ree.es'

get_archives = '/en/datos/mercados/precios-mercados-tiempo-real'

headers = {'Accept': 'application/json',
           'Content-Type': 'application/json',
           'Host': 'apidatos.ree.es'}

params = {'start_date': '2021-11-01T00:00', 'end_date': '2021-11-02T00:00', 'time_trunc':'hour'}

# %% [markdown]
# We are now looking at data regarding the **precios-mercados-tiempo-real** (look at the request archive above). We will find out what this archives contains once we have transferred the data.

# %% [markdown]
# We can write now the request according to the `requests` library and its `get` method. That is how you create a GET HTTP method with this library, which is very intuitive and easy to use.

# %%
response = requests.get(endpoint+get_archives, headers=headers, params=params)

# %% [markdown]
# After that, we can check if the request is correct or not according to the response we get from the API.

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# In this case, the response we get is **200**, meaning that is has been accepted and the connection is established.
# There are different codes that tell us which is our connection status between us and the API. Please, have a look yourself at the possible outcomes of http request.

# %%
status = response.status_code

#Check the status code
if status < 200:
    print('informational')
    # If the status code is 200, treat the information.
elif status >= 200 and status < 300:
    print('Connection is established')
    #okBehavior(response) # runs the function to get list of archives
elif status >= 300 and status < 400:
    print('redirection')
elif status >= 400 and status < 500:
    print('client error')
else:
    print('server error')
# Out:
# Connection is established

# %% [markdown]
# ### Access the data

# %% [markdown]
# The data are sent under the form of a json file. By calling the `json` method on the request object, we can access and store the transferred data. Have a look at all the IDs available for us to obtain data.

# %%
# accessing data by means of a json object
data_json = response.json()

# %%
data_json
# Out:
# {'data': {'type': 'Precios mercado peninsular en tiempo real',
#   'id': 'mer13',
#   'attributes': {'title': 'Precios mercado peninsular en tiempo real',
#    'last-update': '2023-05-19T08:50:06.000+02:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'PVPC',
#    'id': '1001',
#    'groupId': None,
#    'attributes': {'title': 'PVPC',
#     'description': None,
#     'color': '#ffcf09',
#     'icon': None,
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2023-05-19T08:50:06.000+02:00',
#     'values': [{'value': 116.38,
#       'percentage': 0.5974025974025974,
#       'datetime': '2021-11-01T00:00:00.000+01:00'},
#      {'value': 90.29,
#       'percentage': 0.6211902304781561,
#       'datetime': '2021-11-01T01:00:00.000+01:00'},
#      {'value': 78.75,
#       'percentage': 0.6419662509170946,
#       'datetime': '2021-11-01T02:00:00.000+01:00'},
#      {'value': 55.28,
#       'percentage': 0.7148583990689255,
#       'datetime': '2021-11-01T03:00:00.000+01:00'},
#      {'value': 48.11,
#       'percentage': 0.7623197591506893,
#       'datetime': '2021-11-01T04:00:00.000+01:00'},
#      {'value': 78.37,
#       'percentage': 0.6560354930520677,
#       'datetime': '2021-11-01T05:00:00.000+01:00'},
#      {'value': 96.4,
#       'percentage': 0.6231818475661,
#       'datetime': '2021-11-01T06:00:00.000+01:00'},
#      {'value': 115.06,
#       'percentage': 0.5974039460020768,
#       'datetime': '2021-11-01T07:00:00.000+01:00'},
#      {'value': 126.32,
#       'percentage': 0.5871798447450378,
#       'datetime': '2021-11-01T08:00:00.000+01:00'},
#      {'value': 120.93,
#       'percentage': 0.5860431306033438,
#       'datetime': '2021-11-01T09:00:00.000+01:00'},
#      {'value': 112.4,
#       'percentage': 0.574642126789366,
#       'datetime': '2021-11-01T10:00:00.000+01:00'},
#      {'value': 106.24,
#       'percentage': 0.5756705499864535,
#       'datetime': '2021-11-01T11:00:00.000+01:00'},
#      {'value': 106.85,
#       'percentage': 0.5749878921595006,
#       'datetime': '2021-11-01T12:00:00.000+01:00'},
#      {'value': 97.26,
#       'percentage': 0.5793423874195854,
#       'datetime': '2021-11-01T13:00:00.000+01:00'},
#      {'value': 85.58,
#       'percentage': 0.586485745614035,
#       'datetime': '2021-11-01T14:00:00.000+01:00'},
#      {'value': 99.64,
#       'percentage': 0.5805173619202983,
#       'datetime': '2021-11-01T15:00:00.000+01:00'},
#      {'value': 118.75,
#       'percentage': 0.5828220858895705,
#       'datetime': '2021-11-01T16:00:00.000+01:00'},
#      {'value': 172.94,
#       'percentage': 0.5618035928921807,
#       'datetime': '2021-11-01T17:00:00.000+01:00'},
#      {'value': 226.97,
#       'percentage': 0.553625875064029,
#       'datetime': '2021-11-01T18:00:00.000+01:00'},
#      {'value': 220.7,
#       'percentage': 0.5509236145781328,
#       'datetime': '2021-11-01T19:00:00.000+01:00'},
#      {'value': 201.86,
#       'percentage': 0.5531320217021976,
#       'datetime': '2021-11-01T20:00:00.000+01:00'},
#      {'value': 189.16,
#       'percentage': 0.5552587548067045,
#       'datetime': '2021-11-01T21:00:00.000+01:00'},
#      {'value': 186.51,
#       'percentage': 0.5586138732478735,
#       'datetime': '2021-11-01T22:00:00.000+01:00'},
#      {'value': 173.15,
#       'percentage': 0.562084077260185,
#       'datetime': '2021-11-01T23:00:00.000+01:00'},
#      {'value': 150.42,
#       'percentage': 0.5751539020380071,
#       'datetime': '2021-11-02T00:00:00.000+01:00'}]}},
#   {'type': 'Spot market price',
#    'id': '600',
#    'groupId': None,
#    'attributes': {'title': 'Spot market price',
#     'description': None,
#     'color': '#df4a32',
#     'icon': None,
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2021-11-01T14:01:13.000+01:00',
#     'values': [{'value': 78.43,
#       'percentage': 0.4025974025974026,
#       'datetime': '2021-11-01T00:00:00.000+01:00'},
#      {'value': 55.06,
#       'percentage': 0.3788097695218438,
#       'datetime': '2021-11-01T01:00:00.000+01:00'},
#      {'value': 43.92,
#       'percentage': 0.35803374908290536,
#       'datetime': '2021-11-01T02:00:00.000+01:00'},
#      {'value': 22.05,
#       'percentage': 0.28514160093107466,
#       'datetime': '2021-11-01T03:00:00.000+01:00'},
#      {'value': 15,
#       'percentage': 0.23768024084931072,
#       'datetime': '2021-11-01T04:00:00.000+01:00'},
#      {'value': 41.09,
#       'percentage': 0.34396450694793235,
#       'datetime': '2021-11-01T05:00:00.000+01:00'},
#      {'value': 58.29,
#       'percentage': 0.37681815243390004,
#       'datetime': '2021-11-01T06:00:00.000+01:00'},
#      {'value': 77.54,
#       'percentage': 0.40259605399792314,
#       'datetime': '2021-11-01T07:00:00.000+01:00'},
#      {'value': 88.81,
#       'percentage': 0.41282015525496213,
#       'datetime': '2021-11-01T08:00:00.000+01:00'},
#      {'value': 85.42,
#       'percentage': 0.4139568693966561,
#       'datetime': '2021-11-01T09:00:00.000+01:00'},
#      {'value': 83.2,
#       'percentage': 0.4253578732106339,
#       'datetime': '2021-11-01T10:00:00.000+01:00'},
#      {'value': 78.31,
#       'percentage': 0.42432945001354644,
#       'datetime': '2021-11-01T11:00:00.000+01:00'},
#      {'value': 78.98,
#       'percentage': 0.4250121078404994,
#       'datetime': '2021-11-01T12:00:00.000+01:00'},
#      {'value': 70.62,
#       'percentage': 0.4206576125804146,
#       'datetime': '2021-11-01T13:00:00.000+01:00'},
#      {'value': 60.34,
#       'percentage': 0.4135142543859649,
#       'datetime': '2021-11-01T14:00:00.000+01:00'},
#      {'value': 72,
#       'percentage': 0.4194826380797017,
#       'datetime': '2021-11-01T15:00:00.000+01:00'},
#      {'value': 85,
#       'percentage': 0.4171779141104294,
#       'datetime': '2021-11-01T16:00:00.000+01:00'},
#      {'value': 134.89,
#       'percentage': 0.4381964071078192,
#       'datetime': '2021-11-01T17:00:00.000+01:00'},
#      {'value': 183,
#       'percentage': 0.4463741249359709,
#       'datetime': '2021-11-01T18:00:00.000+01:00'},
#      {'value': 179.9,
#       'percentage': 0.4490763854218672,
#       'datetime': '2021-11-01T19:00:00.000+01:00'},
#      {'value': 163.08,
#       'percentage': 0.44686797829780234,
#       'datetime': '2021-11-01T20:00:00.000+01:00'},
#      {'value': 151.51,
#       'percentage': 0.4447412451932956,
#       'datetime': '2021-11-01T21:00:00.000+01:00'},
#      {'value': 147.37,
#       'percentage': 0.4413861267521265,
#       'datetime': '2021-11-01T22:00:00.000+01:00'},
#      {'value': 134.9,
#       'percentage': 0.43791592273981494,
#       'datetime': '2021-11-01T23:00:00.000+01:00'},
#      {'value': 111.11,
#       'percentage': 0.4248460979619929,
#       'datetime': '2021-11-02T00:00:00.000+01:00'}]}}]}

# %% [markdown]
# For a better visualization of the json content, you can use this tool (https://jsonformatter.curiousconcept.com). This helps in understanding the structure of the json file and access the desired data.
# You can find out using the suggested tool that the response to the request contain the desired substructures.

# %% [markdown]
# The **data** struct contains meta-data about your request.
# The **included** struct contains the actual data.
# This contains 2 additional substructure:
#
#     - "PVPC" or Voluntary price for the small consumer - Precio Voluntario Pequeno Consumidor (€/MWh)
#     - "Precio mercado spot" or **Spot market price** (€/MWh)
#
# - PVPC is the price of energy for the REGULATED market
# - Spot market price is the price of energy for the FREE market
#
# Let's try to extract both.
#
# NB: The spot market price can be also called the "Day-Ahead Market" price (DAM) which is contracted the same day for the next one. Prices are defined for each hour.
#
# To access the actual values it is needed to access some more substructures ("attributes" and "values")

# %%
pvpc_data = data_json['included'][0]
spot_market_data = data_json['included'][1]

pvpc_values = pvpc_data['attributes']['values']
spot_values = spot_market_data['attributes']['values']

# %% [markdown]
# ### Store the data on local variables

# %% [markdown]
# Let's focus on the spot market price first.

# %%
spot_values
# Out:
# [{'value': 78.43,
#   'percentage': 0.4025974025974026,
#   'datetime': '2021-11-01T00:00:00.000+01:00'},
#  {'value': 55.06,
#   'percentage': 0.3788097695218438,
#   'datetime': '2021-11-01T01:00:00.000+01:00'},
#  {'value': 43.92,
#   'percentage': 0.35803374908290536,
#   'datetime': '2021-11-01T02:00:00.000+01:00'},
#  {'value': 22.05,
#   'percentage': 0.28514160093107466,
#   'datetime': '2021-11-01T03:00:00.000+01:00'},
#  {'value': 15,
#   'percentage': 0.23768024084931072,
#   'datetime': '2021-11-01T04:00:00.000+01:00'},
#  {'value': 41.09,
#   'percentage': 0.34396450694793235,
#   'datetime': '2021-11-01T05:00:00.000+01:00'},
#  {'value': 58.29,
#   'percentage': 0.37681815243390004,
#   'datetime': '2021-11-01T06:00:00.000+01:00'},
#  {'value': 77.54,
#   'percentage': 0.40259605399792314,
#   'datetime': '2021-11-01T07:00:00.000+01:00'},
#  {'value': 88.81,
#   'percentage': 0.41282015525496213,
#   'datetime': '2021-11-01T08:00:00.000+01:00'},
#  {'value': 85.42,
#   'percentage': 0.4139568693966561,
#   'datetime': '2021-11-01T09:00:00.000+01:00'},
#  {'value': 83.2,
#   'percentage': 0.4253578732106339,
#   'datetime': '2021-11-01T10:00:00.000+01:00'},
#  {'value': 78.31,
#   'percentage': 0.42432945001354644,
#   'datetime': '2021-11-01T11:00:00.000+01:00'},
#  {'value': 78.98,
#   'percentage': 0.4250121078404994,
#   'datetime': '2021-11-01T12:00:00.000+01:00'},
#  {'value': 70.62,
#   'percentage': 0.4206576125804146,
#   'datetime': '2021-11-01T13:00:00.000+01:00'},
#  {'value': 60.34,
#   'percentage': 0.4135142543859649,
#   'datetime': '2021-11-01T14:00:00.000+01:00'},
#  {'value': 72,
#   'percentage': 0.4194826380797017,
#   'datetime': '2021-11-01T15:00:00.000+01:00'},
#  {'value': 85,
#   'percentage': 0.4171779141104294,
#   'datetime': '2021-11-01T16:00:00.000+01:00'},
#  {'value': 134.89,
#   'percentage': 0.4381964071078192,
#   'datetime': '2021-11-01T17:00:00.000+01:00'},
#  {'value': 183,
#   'percentage': 0.4463741249359709,
#   'datetime': '2021-11-01T18:00:00.000+01:00'},
#  {'value': 179.9,
#   'percentage': 0.4490763854218672,
#   'datetime': '2021-11-01T19:00:00.000+01:00'},
#  {'value': 163.08,
#   'percentage': 0.44686797829780234,
#   'datetime': '2021-11-01T20:00:00.000+01:00'},
#  {'value': 151.51,
#   'percentage': 0.4447412451932956,
#   'datetime': '2021-11-01T21:00:00.000+01:00'},
#  {'value': 147.37,
#   'percentage': 0.4413861267521265,
#   'datetime': '2021-11-01T22:00:00.000+01:00'},
#  {'value': 134.9,
#   'percentage': 0.43791592273981494,
#   'datetime': '2021-11-01T23:00:00.000+01:00'},
#  {'value': 111.11,
#   'percentage': 0.4248460979619929,
#   'datetime': '2021-11-02T00:00:00.000+01:00'}]

# %% [markdown]
# Create local structure in your python environment and fill them with data

# %%
prices = []
times = []

# %%
for data_point in spot_values:
    #print(time_period['value'])
    prices.append(data_point['value'])
    times.append(data_point['datetime'])
    print(f"Spot price at {data_point['datetime']} is {data_point['value']} €/MWh")
# Out:
# Spot price at 2021-11-01T00:00:00.000+01:00 is 78.43 €/MWh
# Spot price at 2021-11-01T01:00:00.000+01:00 is 55.06 €/MWh
# Spot price at 2021-11-01T02:00:00.000+01:00 is 43.92 €/MWh
# Spot price at 2021-11-01T03:00:00.000+01:00 is 22.05 €/MWh
# Spot price at 2021-11-01T04:00:00.000+01:00 is 15 €/MWh
# Spot price at 2021-11-01T05:00:00.000+01:00 is 41.09 €/MWh
# Spot price at 2021-11-01T06:00:00.000+01:00 is 58.29 €/MWh
# Spot price at 2021-11-01T07:00:00.000+01:00 is 77.54 €/MWh
# Spot price at 2021-11-01T08:00:00.000+01:00 is 88.81 €/MWh
# Spot price at 2021-11-01T09:00:00.000+01:00 is 85.42 €/MWh
# Spot price at 2021-11-01T10:00:00.000+01:00 is 83.2 €/MWh
# Spot price at 2021-11-01T11:00:00.000+01:00 is 78.31 €/MWh
# Spot price at 2021-11-01T12:00:00.000+01:00 is 78.98 €/MWh
# Spot price at 2021-11-01T13:00:00.000+01:00 is 70.62 €/MWh
# Spot price at 2021-11-01T14:00:00.000+01:00 is 60.34 €/MWh
# Spot price at 2021-11-01T15:00:00.000+01:00 is 72 €/MWh
# Spot price at 2021-11-01T16:00:00.000+01:00 is 85 €/MWh
# Spot price at 2021-11-01T17:00:00.000+01:00 is 134.89 €/MWh
# Spot price at 2021-11-01T18:00:00.000+01:00 is 183 €/MWh
# Spot price at 2021-11-01T19:00:00.000+01:00 is 179.9 €/MWh
# Spot price at 2021-11-01T20:00:00.000+01:00 is 163.08 €/MWh
# Spot price at 2021-11-01T21:00:00.000+01:00 is 151.51 €/MWh
# Spot price at 2021-11-01T22:00:00.000+01:00 is 147.37 €/MWh
# Spot price at 2021-11-01T23:00:00.000+01:00 is 134.9 €/MWh
# Spot price at 2021-11-02T00:00:00.000+01:00 is 111.11 €/MWh

# %% [markdown]
# Now that is what we have

# %%
prices
# Out:
# [78.43,
#  55.06,
#  43.92,
#  22.05,
#  15,
#  41.09,
#  58.29,
#  77.54,
#  88.81,
#  85.42,
#  83.2,
#  78.31,
#  78.98,
#  70.62,
#  60.34,
#  72,
#  85,
#  134.89,
#  183,
#  179.9,
#  163.08,
#  151.51,
#  147.37,
#  134.9,
#  111.11]

# %%
times
# Out:
# ['2021-11-01T00:00:00.000+01:00',
#  '2021-11-01T01:00:00.000+01:00',
#  '2021-11-01T02:00:00.000+01:00',
#  '2021-11-01T03:00:00.000+01:00',
#  '2021-11-01T04:00:00.000+01:00',
#  '2021-11-01T05:00:00.000+01:00',
#  '2021-11-01T06:00:00.000+01:00',
#  '2021-11-01T07:00:00.000+01:00',
#  '2021-11-01T08:00:00.000+01:00',
#  '2021-11-01T09:00:00.000+01:00',
#  '2021-11-01T10:00:00.000+01:00',
#  '2021-11-01T11:00:00.000+01:00',
#  '2021-11-01T12:00:00.000+01:00',
#  '2021-11-01T13:00:00.000+01:00',
#  '2021-11-01T14:00:00.000+01:00',
#  '2021-11-01T15:00:00.000+01:00',
#  '2021-11-01T16:00:00.000+01:00',
#  '2021-11-01T17:00:00.000+01:00',
#  '2021-11-01T18:00:00.000+01:00',
#  '2021-11-01T19:00:00.000+01:00',
#  '2021-11-01T20:00:00.000+01:00',
#  '2021-11-01T21:00:00.000+01:00',
#  '2021-11-01T22:00:00.000+01:00',
#  '2021-11-01T23:00:00.000+01:00',
#  '2021-11-02T00:00:00.000+01:00']

# %% [markdown]
# ### Plot the spot market price - DAM price

# %% [markdown]
# For a better plotting experience, it is convenient to have a proper data type. *times* is a list of strings. Actually it contains datetime data so we want to treat it as such. We need to use a python library called *datetime*

# %%
# Convert each string to datetime object
times = [datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%S.%f%z") for date_str in times]

# %%
matplotlib.rc('xtick', labelsize=15)
matplotlib.rc('ytick', labelsize=15)
plt.style.use('ggplot')

plt.figure(figsize=(20,10))
plt.plot(times, prices, 'r', linewidth=1.5, marker='.')
plt.title(f"Spot market prices", fontsize=20)
plt.xlabel('Hour', fontsize=20 )
plt.ylabel('Price [€/MWh]', fontsize=20)
plt.show()

# %% [markdown]
# ### Changing Dates

# %% [markdown]
# We could try to change the dates and ask for more recent prices. Let's make a new request, changing the desired parameters:

# %%
params = {'start_date': '2022-11-01T00:00', 'end_date': '2022-11-15T00:00', 'time_trunc':'hour'}

# %%
response = requests.get(endpoint+get_archives, headers=headers, params=params)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# Let's repeat the process of extracting the data in a new structure (without plotting for brevity)

# %%
data_json_new = response.json()

# %%
pvpc_data_new = data_json_new['included'][0]
spot_market_data_new = data_json_new['included'][1]

pvpc_values_new = pvpc_data_new['attributes']['values']
spot_values_new = spot_market_data_new['attributes']['values']

# %% [markdown]
# Looking again at the spot market price only:

# %%
prices_new = []
times_new = []
for data_point in spot_values_new:
    prices_new.append(data_point['value'])
    times_new.append(data_point['datetime'])

# %% [markdown]
# Let's plot and compare the new data

# %%
plt.figure(figsize=(20,10))
plt.plot(prices_new, 'r', linewidth=1.5, marker='.')
plt.title(f"Spot market prices", fontsize=20)
plt.xlabel('Hour', fontsize=20 )
plt.ylabel('Price [€/MWh]', fontsize=20)
plt.show()

# %% [markdown]
# Let's look for the most updated price signals.
# We need to use teh python `datetime` library for this. The approach is to generate the actual time in UTC time coordinates and add the desired time step for the analysis. Spot market prices are generated today for tomorrow and are available from 12PM when the market closes. If you are running the code after your 12PM you should be able to see DAM prices for tomorrow.
#
# Mind that datetime objects have to be transformed into strings, follwing the required format specified in the parameters of the API documentation, otherwise it will not work.

# %%
start_date = datetime.now()
end_date = start_date + timedelta(hours=24)             # add one day to see prices for tomorrow
# transform into strings with a minute resolution
end_date = end_date.strftime('%Y-%m-%dT%H:%M')
start_date = start_date.strftime('%Y-%m-%dT%H:%M')
# check
end_date
# Out:
# '2025-11-21T15:50'

# %%
start_date
# Out:
# '2025-11-20T15:50'

# %% [markdown]
# Update the parameters of the API request with the new structures

# %%
params = {'start_date': start_date, 'end_date': end_date, 'time_trunc':'hour'}
response = requests.get(endpoint+get_archives, headers=headers, params=params)
response
# Out:
# <Response [200]>

# %% [markdown]
# Extract values just as before

# %%
data_json = response.json()
data_json
# Out:
# {'data': {'type': 'Precios mercado peninsular en tiempo real',
#   'id': 'mer13',
#   'attributes': {'title': 'Precios mercado peninsular en tiempo real',
#    'last-update': '2025-11-19T20:46:35.000+01:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'PVPC',
#    'id': '1001',
#    'groupId': None,
#    'attributes': {'title': 'PVPC',
#     'description': None,
#     'color': '#ffcf09',
#     'icon': None,
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2025-11-19T20:46:35.000+01:00',
#     'values': [{'value': 137.72,
#       'percentage': 0.6810404509939669,
#       'datetime': '2025-11-20T16:00:00.000+01:00'},
#      {'value': 164.63,
#       'percentage': 0.6465459686604093,
#       'datetime': '2025-11-20T17:00:00.000+01:00'},
#      {'value': 247.95,
#       'percentage': 1,
#       'datetime': '2025-11-20T18:00:00.000+01:00'},
#      {'value': 256.82,
#       'percentage': 1,
#       'datetime': '2025-11-20T19:00:00.000+01:00'},
#      {'value': 256.83,
#       'percentage': 1,
#       'datetime': '2025-11-20T20:00:00.000+01:00'},
#      {'value': 235.37,
#       'percentage': 1,
#       'datetime': '2025-11-20T21:00:00.000+01:00'},
#      {'value': 166.7,
#       'percentage': 1,
#       'datetime': '2025-11-20T22:00:00.000+01:00'},
#      {'value': 149.78,
#       'percentage': 1,
#       'datetime': '2025-11-20T23:00:00.000+01:00'}]}},
#   {'type': 'Spot market price',
#    'id': '600',
#    'groupId': None,
#    'attributes': {'title': 'Spot market price',
#     'description': None,
#     'color': '#df4a32',
#     'icon': None,
#     'type': None,
#     'magnitude': 'price',
#     'composite': False,
#     'last-update': '2025-11-20T14:32:13.000+01:00',
#     'values': [{'value': 64.5,
#       'percentage': 0.318959549006033,
#       'datetime': '2025-11-20T16:00:00.000+01:00'},
#      {'value': 68.5,
#       'percentage': 1,
#       'datetime': '2025-11-20T16:15:00.000+01:00'},
#      {'value': 80.75,
#       'percentage': 1,
#       'datetime': '2025-11-20T16:30:00.000+01:00'},
#      {'value': 95,
#       'percentage': 1,
#       'datetime': '2025-11-20T16:45:00.000+01:00'},
#      {'value': 90,
#       'percentage': 0.3534540313395908,
#       'datetime': '2025-11-20T17:00:00.000+01:00'},
#      {'value': 104.4,
#       'percentage': 1,
#       'datetime': '2025-11-20T17:15:00.000+01:00'},
#      {'value': 105.92,
#       'percentage': 1,
#       'datetime': '2025-11-20T17:30:00.000+01:00'},
#      {'value': 111.19,
#       'percentage': 1,
#       'datetime': '2025-11-20T17:45:00.000+01:00'},
#      {'value': 107.56,
#       'percentage': 1,
#       'datetime': '2025-11-20T18:00:00.000+01:00'},
#      {'value': 115.35,
#       'percentage': 1,
#       'datetime': '2025-11-20T18:15:00.000+01:00'},
#      {'value': 120,
#       'percentage': 1,
#       'datetime': '2025-11-20T18:30:00.000+01:00'},
#      {'value': 123.41,
#       'percentage': 1,
#       'datetime': '2025-11-20T18:45:00.000+01:00'},
#      {'value': 122.18,
#       'percentage': 1,
#       'datetime': '2025-11-20T19:00:00.000+01:00'},
#      {'value': 124,
#       'percentage': 1,
#       'datetime': '2025-11-20T19:15:00.000+01:00'},
#      {'value': 125.48,
#       'percentage': 1,
#       'datetime': '2025-11-20T19:30:00.000+01:00'},
#      {'value': 125.88,
#       'percentage': 1,
#       'datetime': '2025-11-20T19:45:00.000+01:00'},
#      {'value': 130.01,
#       'percentage': 1,
#       'datetime': '2025-11-20T20:00:00.000+01:00'},
#      {'value': 130.01,
#       'percentage': 1,
#       'datetime': '2025-11-20T20:15:00.000+01:00'},
#      {'value': 125.48,
#       'percentage': 1,
#       'datetime': '2025-11-20T20:30:00.000+01:00'},
#      {'value': 114.91,
#       'percentage': 1,
#       'datetime': '2025-11-20T20:45:00.000+01:00'},
#      {'value': 107.34,
#       'percentage': 1,
#       'datetime': '2025-11-20T21:00:00.000+01:00'},
#      {'value': 105.98,
#       'percentage': 1,
#       'datetime': '2025-11-20T21:15:00.000+01:00'},
#      {'value': 105.2,
#       'percentage': 1,
#       'datetime': '2025-11-20T21:30:00.000+01:00'},
#      {'value': 104.36,
#       'percentage': 1,
#       'datetime': '2025-11-20T21:45:00.000+01:00'},
#      {'value': 104.36,
#       'percentage': 1,
#       'datetime': '2025-11-20T22:00:00.000+01:00'},
#      {'value': 101.87,
#       'percentage': 1,
#       'datetime': '2025-11-20T22:15:00.000+01:00'},
#      {'value': 102.62,
#       'percentage': 1,
#       'datetime': '2025-11-20T22:30:00.000+01:00'},
#      {'value': 95,
#       'percentage': 1,
#       'datetime': '2025-11-20T22:45:00.000+01:00'},
#      {'value': 100,
#       'percentage': 1,
#       'datetime': '2025-11-20T23:00:00.000+01:00'},
#      {'value': 90,
#       'percentage': 1,
#       'datetime': '2025-11-20T23:15:00.000+01:00'},
#      {'value': 85,
#       'percentage': 1,
#       'datetime': '2025-11-20T23:30:00.000+01:00'},
#      {'value': 82,
#       'percentage': 1,
#       'datetime': '2025-11-20T23:45:00.000+01:00'},
#      {'value': 83.88,
#       'percentage': 1,
#       'datetime': '2025-11-21T00:00:00.000+01:00'},
#      {'value': 75,
#       'percentage': 1,
#       'datetime': '2025-11-21T00:15:00.000+01:00'},
#      {'value': 69.32,
#       'percentage': 1,
#       'datetime': '2025-11-21T00:30:00.000+01:00'},
#      {'value': 64.5,
#       'percentage': 1,
#       'datetime': '2025-11-21T00:45:00.000+01:00'},
#      {'value': 68.05,
#       'percentage': 1,
#       'datetime': '2025-11-21T01:00:00.000+01:00'},
#      {'value': 67.22,
#       'percentage': 1,
#       'datetime': '2025-11-21T01:15:00.000+01:00'},
#      {'value': 62.9,
#       'percentage': 1,
#       'datetime': '2025-11-21T01:30:00.000+01:00'},
#      {'value': 59.27,
#       'percentage': 1,
#       'datetime': '2025-11-21T01:45:00.000+01:00'},
#      {'value': 67.22,
#       'percentage': 1,
#       'datetime': '2025-11-21T02:00:00.000+01:00'},
#      {'value': 62.9,
#       'percentage': 1,
#       'datetime': '2025-11-21T02:15:00.000+01:00'},
#      {'value': 60,
#       'percentage': 1,
#       'datetime': '2025-11-21T02:30:00.000+01:00'},
#      {'value': 59.27,
#       'percentage': 1,
#       'datetime': '2025-11-21T02:45:00.000+01:00'},
#      {'value': 58.89,
#       'percentage': 1,
#       'datetime': '2025-11-21T03:00:00.000+01:00'},
#      {'value': 58.57,
#       'percentage': 1,
#       'datetime': '2025-11-21T03:15:00.000+01:00'},
#      {'value': 58.44,
#       'percentage': 1,
#       'datetime': '2025-11-21T03:30:00.000+01:00'},
#      {'value': 58.44,
#       'percentage': 1,
#       'datetime': '2025-11-21T03:45:00.000+01:00'},
#      {'value': 58.31,
#       'percentage': 1,
#       'datetime': '2025-11-21T04:00:00.000+01:00'},
#      {'value': 58.05,
#       'percentage': 1,
#       'datetime': '2025-11-21T04:15:00.000+01:00'},
#      {'value': 58.31,
#       'percentage': 1,
#       'datetime': '2025-11-21T04:30:00.000+01:00'},
#      {'value': 58.44,
#       'percentage': 1,
#       'datetime': '2025-11-21T04:45:00.000+01:00'},
#      {'value': 48,
#       'percentage': 1,
#       'datetime': '2025-11-21T05:00:00.000+01:00'},
#      {'value': 50.99,
#       'percentage': 1,
#       'datetime': '2025-11-21T05:15:00.000+01:00'},
#      {'value': 55,
#       'percentage': 1,
#       'datetime': '2025-11-21T05:30:00.000+01:00'},
#      {'value': 57.92,
#       'percentage': 1,
#       'datetime': '2025-11-21T05:45:00.000+01:00'},
#      {'value': 57.79,
#       'percentage': 1,
#       'datetime': '2025-11-21T06:00:00.000+01:00'},
#      {'value': 58.31,
#       'percentage': 1,
#       'datetime': '2025-11-21T06:15:00.000+01:00'},
#      {'value': 59.1,
#       'percentage': 1,
#       'datetime': '2025-11-21T06:30:00.000+01:00'},
#      {'value': 62.8,
#       'percentage': 1,
#       'datetime': '2025-11-21T06:45:00.000+01:00'},
#      {'value': 62.73,
#       'percentage': 1,
#       'datetime': '2025-11-21T07:00:00.000+01:00'},
#      {'value': 68.05,
#       'percentage': 1,
#       'datetime': '2025-11-21T07:15:00.000+01:00'},
#      {'value': 74.9,
#       'percentage': 1,
#       'datetime': '2025-11-21T07:30:00.000+01:00'},
#      {'value': 82.06,
#       'percentage': 1,
#       'datetime': '2025-11-21T07:45:00.000+01:00'},
#      {'value': 84,
#       'percentage': 1,
#       'datetime': '2025-11-21T08:00:00.000+01:00'},
#      {'value': 80,
#       'percentage': 1,
#       'datetime': '2025-11-21T08:15:00.000+01:00'},
#      {'value': 70,
#       'percentage': 1,
#       'datetime': '2025-11-21T08:30:00.000+01:00'},
#      {'value': 61.43,
#       'percentage': 1,
#       'datetime': '2025-11-21T08:45:00.000+01:00'},
#      {'value': 64.64,
#       'percentage': 1,
#       'datetime': '2025-11-21T09:00:00.000+01:00'},
#      {'value': 40.02,
#       'percentage': 1,
#       'datetime': '2025-11-21T09:15:00.000+01:00'},
#      {'value': 6,
#       'percentage': 1,
#       'datetime': '2025-11-21T09:30:00.000+01:00'},
#      {'value': 0.65,
#       'percentage': 1,
#       'datetime': '2025-11-21T09:45:00.000+01:00'},
#      {'value': 0.99,
#       'percentage': 1,
#       'datetime': '2025-11-21T10:00:00.000+01:00'},
#      {'value': 0.01,
#       'percentage': 1,
#       'datetime': '2025-11-21T10:15:00.000+01:00'},
#      {'value': 0,
#       'percentage': 0,
#       'datetime': '2025-11-21T10:30:00.000+01:00'},
#      {'value': 0,
#       'percentage': 0,
#       'datetime': '2025-11-21T10:45:00.000+01:00'},
#      {'value': 0.69,
#       'percentage': 1,
#       'datetime': '2025-11-21T11:00:00.000+01:00'},
#      {'value': 0.16,
#       'percentage': 1,
#       'datetime': '2025-11-21T11:15:00.000+01:00'},
#      {'value': 0.16,
#       'percentage': 1,
#       'datetime': '2025-11-21T11:30:00.000+01:00'},
#      {'value': 0.16,
#       'percentage': 1,
#       'datetime': '2025-11-21T11:45:00.000+01:00'},
#      {'value': 0.82,
#       'percentage': 1,
#       'datetime': '2025-11-21T12:00:00.000+01:00'},
#      {'value': 0.82,
#       'percentage': 1,
#       'datetime': '2025-11-21T12:15:00.000+01:00'},
#      {'value': 0.66,
#       'percentage': 1,
#       'datetime': '2025-11-21T12:30:00.000+01:00'},
#      {'value': 0.7,
#       'percentage': 1,
#       'datetime': '2025-11-21T12:45:00.000+01:00'},
#      {'value': 0.7,
#       'percentage': 1,
#       'datetime': '2025-11-21T13:00:00.000+01:00'},
#      {'value': 0.83,
#       'percentage': 1,
#       'datetime': '2025-11-21T13:15:00.000+01:00'},
#      {'value': 1,
#       'percentage': 1,
#       'datetime': '2025-11-21T13:30:00.000+01:00'},
#      {'value': 0.75,
#       'percentage': 1,
#       'datetime': '2025-11-21T13:45:00.000+01:00'},
#      {'value': 1,
#       'percentage': 1,
#       'datetime': '2025-11-21T14:00:00.000+01:00'},
#      {'value': 1.5,
#       'percentage': 1,
#       'datetime': '2025-11-21T14:15:00.000+01:00'},
#      {'value': 2.4,
#       'percentage': 1,
#       'datetime': '2025-11-21T14:30:00.000+01:00'},
#      {'value': 2.84,
#       'percentage': 1,
#       'datetime': '2025-11-21T14:45:00.000+01:00'},
#      {'value': 4.84,
#       'percentage': 1,
#       'datetime': '2025-11-21T15:00:00.000+01:00'},
#      {'value': 7.96,
#       'percentage': 1,
#       'datetime': '2025-11-21T15:15:00.000+01:00'},
#      {'value': 16.53,
#       'percentage': 1,
#       'datetime': '2025-11-21T15:30:00.000+01:00'},
#      {'value': 30,
#       'percentage': 1,
#       'datetime': '2025-11-21T15:45:00.000+01:00'}]}}]}

# %% [markdown]
# Let's extract the data we have

# %%
spot_price = data_json["included"][1]["attributes"]["values"][0]["value"]
time_str = data_json["included"][1]["attributes"]["values"][0]["datetime"]
# from string to datetime
time = datetime.strptime(time_str[:16], '%Y-%m-%dT%H:%M')
print(f"Spot market price at {time} is {spot_price} €/MWh")
# Out:
# Spot market price at 2025-11-20 16:00:00 is 64.5 €/MWh

# %%
pvpc = data_json["included"][0]["attributes"]["values"][0]["value"]
time_str = data_json["included"][0]["attributes"]["values"][0]["datetime"]
# from string to datetime
time = datetime.strptime(time_str[:16], '%Y-%m-%dT%H:%M')
print(f"Price the final consumer is paying at {time} is {pvpc} €/MWh")
# Out:
# Price the final consumer is paying at 2025-11-20 16:00:00 is 137.72 €/MWh

# %% [markdown]
# As you can see there is a big difference between the price settled by the regulator and the price in the free market!

# %% [markdown]
# **IMPORTANT**: asking dates prior to year 2021 will return partial data only. This is because there is a problem with the API.
#
# This changes do happen a lot in APIs, because as said they have their own software development cycle (ciclically need maintaince) and might be subjected to change. Do always check out the API documentation to keep trace of the changes.
# API are not perfect tools :) and might contain bugs, missing data, and many more...

# %% [markdown]
# # Now do it yourself!

# %% [markdown]
# ### Build your own request

# %% [markdown]
# Looking at the REE API documentation available online, you can see the several information available (called "widget").
# Each widget belong to a category. Pick the one of your interest and try to stream the desired data from the REE API.
# You would need to set proper parameters for each widget.
# It is important to have a deep look at the API documentation, looking for the type of information that might be of interest for you.
#
# Set your own request parameters here below:

# %%
endpoint = 'https://apidatos.ree.es'
# enter here your desired path to the resource
get_archives = '/path_to_resource/resource_name'
headers = {'Accept': 'application/json',
           'Content-Type': 'application/json',
           'Host': 'apidatos.ree.es'}
params = # choose here your desired parameters: start_date, end_date, time_trunc, geo_trunc, etc ...
# Out:
#   Cell In[32], line 7
#     params = # choose here your desired parameters: start_date, end_date, time_trunc, geo_trunc, etc ...
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# Now you can make your own request

# %%
# type code here

# %% [markdown]
# Check the status of your request

# %%
# type code here

# %% [markdown]
# Problem with your request? meaning any status different than 200.
# Check the problem related with your request and try to fix it. Use the following:

# %%
response.json()

# %% [markdown]
# Change parameters accordingly.

# %% [markdown]
# When your connection is succesfully established. Access the data by means of a json object

# %%
json_data = response.json()
json_data


# type code here to extract data

# %% [markdown]
# Store the data in local python structures

# %%
# type code here

# %% [markdown]
# Print the data for better visualization and analysis

# %%
# type code here

# %% [markdown]
# # Part II: Exercise - REE API

# %% [markdown]
# Going back to the Part 1 of the lab, take the most updated prices for the spot market and the PVPC and compare them in a chart. Draw some conclusions.

# %%
params = {'start_date': '2023-11-01T00:00', 'end_date': '2024-11-02T00:00', 'time_trunc':'hour'}
response = requests.get(endpoint+get_archives, headers=headers, params=params)
response

# %%
pvpc_data_new = data_json_new['included'][0]
spot_market_data_new = data_json_new['included'][1]

pvpc_values_new = pvpc_data_new['attributes']['values']
spot_values_new = spot_market_data_new['attributes']['values']

# %%
pvpc = []
spot = []
times = []
for data_point in spot:
    spot.append(data_point['value'])
    times.append(data_point['datetime'])
for data_point in pvpc:
    pvpc.append(data_point['value'])
    times.append(data_point['datetime'])

# %% [markdown]
# # Part III: CO2 Signal API

# %% [markdown]
# This is a free to use API from the famous **electricitymap.org**.
#
# You can use our API to get access to information about how much carbon is emitted when producing electricity in a country.
# API documentation is available at https://docs.co2signal.com/#introduction
#
# CO2 Signal uses API keys to allow access to the API. You can get an API key by making a request in their website.
# CO2 Signal expects the API key to be included as a header in all requests to the server

# %% [markdown]
# ### Get latest by country code

# %%
my_api_token = 'EUHfe7Ap0YgYSnWJ8xiK'

endpoint = 'https://api.co2signal.com'
get_archive = '/v1/latest'

full_url =  "https://api.electricitymaps.com/v3/carbon-intensity/past-range?start=2025-11-09+17%3A47&end=2025-11-18+18%3A47&temporalGranularity=hourly"
headers = {'auth-token': my_api_token}
params = {'countryCode':'ES'}

# NB: this parameters are asking data for country Italy, but you can change it, based on the info given in the API documentation

# %%
response = requests.get(full_url, headers=headers, params=params)
response
# Out:
# <Response [200]>

# %%
data_json = response.json()
data_json
# Out:
# {'zone': 'ES',
#  'data': [{'zone': 'ES',
#    'carbonIntensity': 172,
#    'datetime': '2025-11-09T17:00:00.000Z',
#    'updatedAt': '2025-11-12T13:25:07.008Z',
#    'createdAt': '2025-11-07T00:10:47.659Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 201,
#    'datetime': '2025-11-09T18:00:00.000Z',
#    'updatedAt': '2025-11-10T18:55:54.989Z',
#    'createdAt': '2025-11-07T00:10:34.062Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 175,
#    'datetime': '2025-11-09T19:00:00.000Z',
#    'updatedAt': '2025-11-11T13:27:30.775Z',
#    'createdAt': '2025-11-07T00:10:34.062Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 225,
#    'datetime': '2025-11-09T20:00:00.000Z',
#    'updatedAt': '2025-11-11T13:27:13.917Z',
#    'createdAt': '2025-11-07T00:10:35.017Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 191,
#    'datetime': '2025-11-09T21:00:00.000Z',
#    'updatedAt': '2025-11-10T21:55:21.214Z',
#    'createdAt': '2025-11-07T00:10:35.017Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 213,
#    'datetime': '2025-11-09T22:00:00.000Z',
#    'updatedAt': '2025-11-10T22:55:44.881Z',
#    'createdAt': '2025-11-07T00:10:35.017Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 148,
#    'datetime': '2025-11-09T23:00:00.000Z',
#    'updatedAt': '2025-11-12T19:10:05.061Z',
#    'createdAt': '2025-11-07T00:10:35.017Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 131,
#    'datetime': '2025-11-10T00:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:56.755Z',
#    'createdAt': '2025-11-07T00:10:35.017Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 132,
#    'datetime': '2025-11-10T01:00:00.000Z',
#    'updatedAt': '2025-11-13T01:26:03.105Z',
#    'createdAt': '2025-11-07T21:55:05.086Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 164,
#    'datetime': '2025-11-10T02:00:00.000Z',
#    'updatedAt': '2025-11-13T01:26:03.105Z',
#    'createdAt': '2025-11-07T21:55:05.086Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 136,
#    'datetime': '2025-11-10T03:00:00.000Z',
#    'updatedAt': '2025-11-13T01:26:03.105Z',
#    'createdAt': '2025-11-07T21:55:05.086Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 139,
#    'datetime': '2025-11-10T04:00:00.000Z',
#    'updatedAt': '2025-11-13T01:25:48.158Z',
#    'createdAt': '2025-11-07T21:55:05.086Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 131,
#    'datetime': '2025-11-10T05:00:00.000Z',
#    'updatedAt': '2025-11-13T01:26:03.105Z',
#    'createdAt': '2025-11-07T21:55:21.806Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 157,
#    'datetime': '2025-11-10T06:00:00.000Z',
#    'updatedAt': '2025-11-13T01:26:03.105Z',
#    'createdAt': '2025-11-07T21:55:21.806Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 193,
#    'datetime': '2025-11-10T07:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:05.086Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 110,
#    'datetime': '2025-11-10T08:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:05.086Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 85,
#    'datetime': '2025-11-10T09:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:05.086Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 116,
#    'datetime': '2025-11-10T10:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:56.755Z',
#    'createdAt': '2025-11-07T21:55:05.086Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 127,
#    'datetime': '2025-11-10T11:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:56.755Z',
#    'createdAt': '2025-11-07T21:55:21.806Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 97,
#    'datetime': '2025-11-10T12:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:21.806Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 93,
#    'datetime': '2025-11-10T13:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:21.806Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 113,
#    'datetime': '2025-11-10T14:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:56.755Z',
#    'createdAt': '2025-11-07T21:55:06.300Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 154,
#    'datetime': '2025-11-10T15:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:06.300Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 217,
#    'datetime': '2025-11-10T16:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:21.806Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 271,
#    'datetime': '2025-11-10T17:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:06.300Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 213,
#    'datetime': '2025-11-10T18:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:06.300Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 193,
#    'datetime': '2025-11-10T19:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:06.300Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 252,
#    'datetime': '2025-11-10T20:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:38.721Z',
#    'createdAt': '2025-11-07T21:55:22.599Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 203,
#    'datetime': '2025-11-10T21:00:00.000Z',
#    'updatedAt': '2025-11-12T23:25:56.755Z',
#    'createdAt': '2025-11-07T21:55:22.599Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 245,
#    'datetime': '2025-11-10T22:00:00.000Z',
#    'updatedAt': '2025-11-11T22:55:16.520Z',
#    'createdAt': '2025-11-08T00:25:45.535Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 198,
#    'datetime': '2025-11-10T23:00:00.000Z',
#    'updatedAt': '2025-11-11T23:56:05.024Z',
#    'createdAt': '2025-11-08T00:25:45.535Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 139,
#    'datetime': '2025-11-11T00:00:00.000Z',
#    'updatedAt': '2025-11-12T00:55:41.693Z',
#    'createdAt': '2025-11-08T00:26:01.282Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 193,
#    'datetime': '2025-11-11T01:00:00.000Z',
#    'updatedAt': '2025-11-12T01:55:32.896Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 200,
#    'datetime': '2025-11-11T02:00:00.000Z',
#    'updatedAt': '2025-11-12T02:55:42.082Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 204,
#    'datetime': '2025-11-11T03:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:18.790Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 152,
#    'datetime': '2025-11-11T04:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:18.790Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 166,
#    'datetime': '2025-11-11T05:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:18.790Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 172,
#    'datetime': '2025-11-11T06:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:18.790Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 208,
#    'datetime': '2025-11-11T07:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:18.790Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 140,
#    'datetime': '2025-11-11T08:00:00.000Z',
#    'updatedAt': '2025-11-12T08:56:13.202Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-11T09:00:00.000Z',
#    'updatedAt': '2025-11-12T09:56:04.280Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-11T10:00:00.000Z',
#    'updatedAt': '2025-11-12T10:25:25.650Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 122,
#    'datetime': '2025-11-11T11:00:00.000Z',
#    'updatedAt': '2025-11-11T15:11:21.493Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 116,
#    'datetime': '2025-11-11T12:00:00.000Z',
#    'updatedAt': '2025-11-11T15:55:43.706Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 102,
#    'datetime': '2025-11-11T13:00:00.000Z',
#    'updatedAt': '2025-11-11T15:55:25.860Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 104,
#    'datetime': '2025-11-11T14:00:00.000Z',
#    'updatedAt': '2025-11-11T20:11:11.210Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 105,
#    'datetime': '2025-11-11T15:00:00.000Z',
#    'updatedAt': '2025-11-11T20:11:28.710Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 123,
#    'datetime': '2025-11-11T16:00:00.000Z',
#    'updatedAt': '2025-11-12T17:10:17.864Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 192,
#    'datetime': '2025-11-11T17:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:24.804Z',
#    'createdAt': '2025-11-09T00:41:19.877Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 142,
#    'datetime': '2025-11-11T18:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:10.727Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 154,
#    'datetime': '2025-11-11T19:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:10.727Z',
#    'createdAt': '2025-11-09T00:41:21.704Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 181,
#    'datetime': '2025-11-11T20:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:24.804Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 114,
#    'datetime': '2025-11-11T21:00:00.000Z',
#    'updatedAt': '2025-11-13T13:40:10.727Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 110,
#    'datetime': '2025-11-11T22:00:00.000Z',
#    'updatedAt': '2025-11-12T22:55:31.624Z',
#    'createdAt': '2025-11-09T00:41:39.615Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 101,
#    'datetime': '2025-11-11T23:00:00.000Z',
#    'updatedAt': '2025-11-12T23:55:07.457Z',
#    'createdAt': '2025-11-09T00:41:21.704Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 126,
#    'datetime': '2025-11-12T00:00:00.000Z',
#    'updatedAt': '2025-11-13T00:55:53.991Z',
#    'createdAt': '2025-11-09T00:41:21.704Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 95,
#    'datetime': '2025-11-12T01:00:00.000Z',
#    'updatedAt': '2025-11-13T01:55:35.172Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 111,
#    'datetime': '2025-11-12T02:00:00.000Z',
#    'updatedAt': '2025-11-13T02:56:36.810Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 118,
#    'datetime': '2025-11-12T03:00:00.000Z',
#    'updatedAt': '2025-11-13T03:55:29.888Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 91,
#    'datetime': '2025-11-12T04:00:00.000Z',
#    'updatedAt': '2025-11-13T04:55:14.272Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 103,
#    'datetime': '2025-11-12T05:00:00.000Z',
#    'updatedAt': '2025-11-14T12:56:48.636Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 85,
#    'datetime': '2025-11-12T06:00:00.000Z',
#    'updatedAt': '2025-11-14T12:57:04.569Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 138,
#    'datetime': '2025-11-12T07:00:00.000Z',
#    'updatedAt': '2025-11-14T12:57:04.569Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 105,
#    'datetime': '2025-11-12T08:00:00.000Z',
#    'updatedAt': '2025-11-12T12:10:04.328Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 83,
#    'datetime': '2025-11-12T09:00:00.000Z',
#    'updatedAt': '2025-11-12T12:10:04.328Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-12T10:00:00.000Z',
#    'updatedAt': '2025-11-12T12:25:12.242Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 92,
#    'datetime': '2025-11-12T11:00:00.000Z',
#    'updatedAt': '2025-11-12T16:10:47.565Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-12T12:00:00.000Z',
#    'updatedAt': '2025-11-12T17:56:10.317Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 88,
#    'datetime': '2025-11-12T13:00:00.000Z',
#    'updatedAt': '2025-11-12T17:56:10.317Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-12T14:00:00.000Z',
#    'updatedAt': '2025-11-12T17:55:56.448Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-12T15:00:00.000Z',
#    'updatedAt': '2025-11-12T17:56:10.317Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 84,
#    'datetime': '2025-11-12T16:00:00.000Z',
#    'updatedAt': '2025-11-13T17:10:03.265Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 128,
#    'datetime': '2025-11-12T17:00:00.000Z',
#    'updatedAt': '2025-11-13T18:10:40.116Z',
#    'createdAt': '2025-11-10T00:40:06.423Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 98,
#    'datetime': '2025-11-12T18:00:00.000Z',
#    'updatedAt': '2025-11-13T19:10:35.164Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 120,
#    'datetime': '2025-11-12T19:00:00.000Z',
#    'updatedAt': '2025-11-13T20:11:29.952Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 93,
#    'datetime': '2025-11-12T20:00:00.000Z',
#    'updatedAt': '2025-11-13T20:55:48.601Z',
#    'createdAt': '2025-11-10T00:40:07.255Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 104,
#    'datetime': '2025-11-12T21:00:00.000Z',
#    'updatedAt': '2025-11-13T22:11:26.385Z',
#    'createdAt': '2025-11-10T00:40:07.255Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 117,
#    'datetime': '2025-11-12T22:00:00.000Z',
#    'updatedAt': '2025-11-13T22:55:25.660Z',
#    'createdAt': '2025-11-10T00:39:50.238Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 118,
#    'datetime': '2025-11-12T23:00:00.000Z',
#    'updatedAt': '2025-11-13T23:55:39.811Z',
#    'createdAt': '2025-11-10T00:40:07.255Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 107,
#    'datetime': '2025-11-13T00:00:00.000Z',
#    'updatedAt': '2025-11-14T00:55:54.704Z',
#    'createdAt': '2025-11-10T00:40:07.255Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 101,
#    'datetime': '2025-11-13T01:00:00.000Z',
#    'updatedAt': '2025-11-14T01:56:15.266Z',
#    'createdAt': '2025-11-11T00:25:03.955Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 99,
#    'datetime': '2025-11-13T02:00:00.000Z',
#    'updatedAt': '2025-11-14T02:55:55.574Z',
#    'createdAt': '2025-11-11T00:25:17.172Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 107,
#    'datetime': '2025-11-13T03:00:00.000Z',
#    'updatedAt': '2025-11-14T03:57:10.508Z',
#    'createdAt': '2025-11-11T02:55:25.098Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 134,
#    'datetime': '2025-11-13T04:00:00.000Z',
#    'updatedAt': '2025-11-14T04:56:17.945Z',
#    'createdAt': '2025-11-11T03:39:02.621Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 123,
#    'datetime': '2025-11-13T05:00:00.000Z',
#    'updatedAt': '2025-11-15T08:55:05.622Z',
#    'createdAt': '2025-11-11T04:40:21.646Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 98,
#    'datetime': '2025-11-13T06:00:00.000Z',
#    'updatedAt': '2025-11-15T08:55:05.622Z',
#    'createdAt': '2025-11-11T05:40:21.976Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 109,
#    'datetime': '2025-11-13T07:00:00.000Z',
#    'updatedAt': '2025-11-15T08:55:05.622Z',
#    'createdAt': '2025-11-11T06:39:59.903Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 119,
#    'datetime': '2025-11-13T08:00:00.000Z',
#    'updatedAt': '2025-11-15T08:55:05.622Z',
#    'createdAt': '2025-11-11T07:40:59.555Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 112,
#    'datetime': '2025-11-13T09:00:00.000Z',
#    'updatedAt': '2025-11-14T09:25:37.208Z',
#    'createdAt': '2025-11-11T08:41:59.637Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 121,
#    'datetime': '2025-11-13T10:00:00.000Z',
#    'updatedAt': '2025-11-14T10:26:17.956Z',
#    'createdAt': '2025-11-11T09:25:44.213Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 125,
#    'datetime': '2025-11-13T11:00:00.000Z',
#    'updatedAt': '2025-11-13T13:10:27.121Z',
#    'createdAt': '2025-11-11T10:40:42.902Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 149,
#    'datetime': '2025-11-13T12:00:00.000Z',
#    'updatedAt': '2025-11-13T14:55:29.093Z',
#    'createdAt': '2025-11-11T11:25:52.077Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 118,
#    'datetime': '2025-11-13T13:00:00.000Z',
#    'updatedAt': '2025-11-13T15:11:14.974Z',
#    'createdAt': '2025-11-11T12:25:45.282Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 158,
#    'datetime': '2025-11-13T14:00:00.000Z',
#    'updatedAt': '2025-11-13T16:10:15.540Z',
#    'createdAt': '2025-11-11T13:27:22.383Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 167,
#    'datetime': '2025-11-13T15:00:00.000Z',
#    'updatedAt': '2025-11-13T17:10:25.098Z',
#    'createdAt': '2025-11-11T14:25:00.705Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 155,
#    'datetime': '2025-11-13T16:00:00.000Z',
#    'updatedAt': '2025-11-14T16:55:47.823Z',
#    'createdAt': '2025-11-11T15:25:24.888Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 102,
#    'datetime': '2025-11-13T17:00:00.000Z',
#    'updatedAt': '2025-11-15T08:55:11.446Z',
#    'createdAt': '2025-11-11T16:26:04.561Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 139,
#    'datetime': '2025-11-13T18:00:00.000Z',
#    'updatedAt': '2025-11-15T08:55:24.786Z',
#    'createdAt': '2025-11-11T17:41:28.950Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 104,
#    'datetime': '2025-11-13T19:00:00.000Z',
#    'updatedAt': '2025-11-14T19:55:21.332Z',
#    'createdAt': '2025-11-11T18:40:47.697Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 88,
#    'datetime': '2025-11-13T20:00:00.000Z',
#    'updatedAt': '2025-11-14T21:11:19.778Z',
#    'createdAt': '2025-11-11T19:26:41.340Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 77,
#    'datetime': '2025-11-13T21:00:00.000Z',
#    'updatedAt': '2025-11-14T22:10:13.070Z',
#    'createdAt': '2025-11-11T20:25:55.840Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 89,
#    'datetime': '2025-11-13T22:00:00.000Z',
#    'updatedAt': '2025-11-14T22:25:07.277Z',
#    'createdAt': '2025-11-11T21:27:01.771Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-13T23:00:00.000Z',
#    'updatedAt': '2025-11-14T23:55:44.848Z',
#    'createdAt': '2025-11-11T22:26:20.607Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 112,
#    'datetime': '2025-11-14T00:00:00.000Z',
#    'updatedAt': '2025-11-15T00:56:16.103Z',
#    'createdAt': '2025-11-11T23:26:23.187Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 97,
#    'datetime': '2025-11-14T01:00:00.000Z',
#    'updatedAt': '2025-11-15T01:26:18.402Z',
#    'createdAt': '2025-11-12T00:40:25.687Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 120,
#    'datetime': '2025-11-14T02:00:00.000Z',
#    'updatedAt': '2025-11-14T04:10:33.966Z',
#    'createdAt': '2025-11-12T00:40:25.687Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 98,
#    'datetime': '2025-11-14T03:00:00.000Z',
#    'updatedAt': '2025-11-15T03:55:17.213Z',
#    'createdAt': '2025-11-12T02:56:03.396Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 77,
#    'datetime': '2025-11-14T04:00:00.000Z',
#    'updatedAt': '2025-11-15T04:55:26.287Z',
#    'createdAt': '2025-11-12T03:55:55.586Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 119,
#    'datetime': '2025-11-14T05:00:00.000Z',
#    'updatedAt': '2025-11-15T05:55:12.321Z',
#    'createdAt': '2025-11-12T04:40:30.860Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 89,
#    'datetime': '2025-11-14T06:00:00.000Z',
#    'updatedAt': '2025-11-15T10:40:48.320Z',
#    'createdAt': '2025-11-12T05:25:42.922Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 101,
#    'datetime': '2025-11-14T07:00:00.000Z',
#    'updatedAt': '2025-11-15T10:40:48.320Z',
#    'createdAt': '2025-11-12T06:26:52.767Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 102,
#    'datetime': '2025-11-14T08:00:00.000Z',
#    'updatedAt': '2025-11-15T08:55:24.786Z',
#    'createdAt': '2025-11-12T07:25:05.147Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 91,
#    'datetime': '2025-11-14T09:00:00.000Z',
#    'updatedAt': '2025-11-15T09:55:00.448Z',
#    'createdAt': '2025-11-12T08:56:20.382Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-14T10:00:00.000Z',
#    'updatedAt': '2025-11-15T10:24:45.208Z',
#    'createdAt': '2025-11-12T09:25:54.596Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 88,
#    'datetime': '2025-11-14T11:00:00.000Z',
#    'updatedAt': '2025-11-14T13:12:06.281Z',
#    'createdAt': '2025-11-12T10:25:19.066Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 121,
#    'datetime': '2025-11-14T12:00:00.000Z',
#    'updatedAt': '2025-11-14T14:56:35.475Z',
#    'createdAt': '2025-11-12T11:25:50.658Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 129,
#    'datetime': '2025-11-14T13:00:00.000Z',
#    'updatedAt': '2025-11-14T15:10:13.327Z',
#    'createdAt': '2025-11-12T12:25:15.152Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 87,
#    'datetime': '2025-11-14T14:00:00.000Z',
#    'updatedAt': '2025-11-14T16:26:54.739Z',
#    'createdAt': '2025-11-12T13:40:44.649Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 90,
#    'datetime': '2025-11-14T15:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-12T14:26:38.314Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 154,
#    'datetime': '2025-11-14T16:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-12T16:25:18.539Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 124,
#    'datetime': '2025-11-14T17:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-12T16:25:18.539Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 110,
#    'datetime': '2025-11-14T18:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-12T17:25:22.966Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 97,
#    'datetime': '2025-11-14T19:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-12T18:25:37.659Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 73,
#    'datetime': '2025-11-14T20:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-12T19:25:24.151Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 82,
#    'datetime': '2025-11-14T21:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-12T20:25:09.631Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 96,
#    'datetime': '2025-11-14T22:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-12T21:25:10.236Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-14T23:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-12T22:25:28.268Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 84,
#    'datetime': '2025-11-15T00:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-12T23:25:50.886Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 99,
#    'datetime': '2025-11-15T01:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T00:41:42.521Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 110,
#    'datetime': '2025-11-15T02:00:00.000Z',
#    'updatedAt': '2025-11-15T04:26:10.743Z',
#    'createdAt': '2025-11-13T00:41:42.521Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 96,
#    'datetime': '2025-11-15T03:00:00.000Z',
#    'updatedAt': '2025-11-16T03:55:55.651Z',
#    'createdAt': '2025-11-13T02:26:05.444Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 88,
#    'datetime': '2025-11-15T04:00:00.000Z',
#    'updatedAt': '2025-11-16T04:26:26.988Z',
#    'createdAt': '2025-11-13T03:25:09.034Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 126,
#    'datetime': '2025-11-15T05:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T04:55:07.718Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 124,
#    'datetime': '2025-11-15T06:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-13T05:26:02.509Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 128,
#    'datetime': '2025-11-15T07:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T06:56:19.545Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-15T08:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T07:55:01.719Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 75,
#    'datetime': '2025-11-15T09:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-13T08:41:53.970Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 81,
#    'datetime': '2025-11-15T10:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-13T09:41:14.315Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 98,
#    'datetime': '2025-11-15T11:00:00.000Z',
#    'updatedAt': '2025-11-15T14:10:39.652Z',
#    'createdAt': '2025-11-13T10:55:16.810Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 111,
#    'datetime': '2025-11-15T12:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T11:25:57.414Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 93,
#    'datetime': '2025-11-15T13:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:42.371Z',
#    'createdAt': '2025-11-13T12:25:29.749Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 115,
#    'datetime': '2025-11-15T14:00:00.000Z',
#    'updatedAt': '2025-11-16T14:25:48.000Z',
#    'createdAt': '2025-11-13T13:25:37.300Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 89,
#    'datetime': '2025-11-15T15:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T14:43:08.291Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 116,
#    'datetime': '2025-11-15T16:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T15:26:37.294Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 104,
#    'datetime': '2025-11-15T17:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T16:41:07.982Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-15T18:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:57.517Z',
#    'createdAt': '2025-11-13T17:10:31.067Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-15T19:00:00.000Z',
#    'updatedAt': '2025-11-17T15:26:03.725Z',
#    'createdAt': '2025-11-13T18:25:20.705Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 73,
#    'datetime': '2025-11-15T20:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:48.446Z',
#    'createdAt': '2025-11-13T19:40:11.761Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 81,
#    'datetime': '2025-11-15T21:00:00.000Z',
#    'updatedAt': '2025-11-17T15:26:03.725Z',
#    'createdAt': '2025-11-13T20:29:03.101Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 95,
#    'datetime': '2025-11-15T22:00:00.000Z',
#    'updatedAt': '2025-11-17T17:40:17.643Z',
#    'createdAt': '2025-11-13T21:40:34.455Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 130,
#    'datetime': '2025-11-15T23:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:48.446Z',
#    'createdAt': '2025-11-13T22:11:48.389Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 136,
#    'datetime': '2025-11-16T00:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:48.446Z',
#    'createdAt': '2025-11-13T23:25:14.336Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 109,
#    'datetime': '2025-11-16T01:00:00.000Z',
#    'updatedAt': '2025-11-17T15:26:03.725Z',
#    'createdAt': '2025-11-14T00:40:35.806Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 135,
#    'datetime': '2025-11-16T02:00:00.000Z',
#    'updatedAt': '2025-11-17T15:26:03.725Z',
#    'createdAt': '2025-11-14T00:40:35.806Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 109,
#    'datetime': '2025-11-16T03:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:36.909Z',
#    'createdAt': '2025-11-14T02:25:56.404Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 130,
#    'datetime': '2025-11-16T04:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:19.893Z',
#    'createdAt': '2025-11-14T03:40:08.824Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 130,
#    'datetime': '2025-11-16T05:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:19.893Z',
#    'createdAt': '2025-11-14T04:25:14.671Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 108,
#    'datetime': '2025-11-16T06:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:19.893Z',
#    'createdAt': '2025-11-14T05:25:18.568Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 148,
#    'datetime': '2025-11-16T07:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:19.893Z',
#    'createdAt': '2025-11-14T06:25:56.491Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 90,
#    'datetime': '2025-11-16T08:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:19.893Z',
#    'createdAt': '2025-11-14T07:25:02.795Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-16T09:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:19.893Z',
#    'createdAt': '2025-11-14T08:40:57.115Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 96,
#    'datetime': '2025-11-16T10:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:36.909Z',
#    'createdAt': '2025-11-14T09:41:36.374Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 77,
#    'datetime': '2025-11-16T11:00:00.000Z',
#    'updatedAt': '2025-11-16T13:11:17.490Z',
#    'createdAt': '2025-11-14T10:42:52.681Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-16T12:00:00.000Z',
#    'updatedAt': '2025-11-17T15:25:48.446Z',
#    'createdAt': '2025-11-14T11:26:39.737Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-16T13:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:36.909Z',
#    'createdAt': '2025-11-14T12:40:55.614Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-16T14:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:19.893Z',
#    'createdAt': '2025-11-14T13:26:14.397Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 113,
#    'datetime': '2025-11-16T15:00:00.000Z',
#    'updatedAt': '2025-11-17T15:26:03.725Z',
#    'createdAt': '2025-11-14T14:41:09.338Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 149,
#    'datetime': '2025-11-16T16:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:40.700Z',
#    'createdAt': '2025-11-14T15:42:16.514Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 156,
#    'datetime': '2025-11-16T17:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:40.700Z',
#    'createdAt': '2025-11-14T16:26:33.139Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 112,
#    'datetime': '2025-11-16T18:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:26.296Z',
#    'createdAt': '2025-11-14T17:25:59.131Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 165,
#    'datetime': '2025-11-16T19:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:26.296Z',
#    'createdAt': '2025-11-14T18:25:32.654Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 167,
#    'datetime': '2025-11-16T20:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:40.700Z',
#    'createdAt': '2025-11-14T19:41:44.197Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 138,
#    'datetime': '2025-11-16T21:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:40.700Z',
#    'createdAt': '2025-11-14T20:27:26.725Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 164,
#    'datetime': '2025-11-16T22:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:26.296Z',
#    'createdAt': '2025-11-14T21:11:46.739Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 141,
#    'datetime': '2025-11-16T23:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:26.296Z',
#    'createdAt': '2025-11-14T22:25:17.249Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 161,
#    'datetime': '2025-11-17T00:00:00.000Z',
#    'updatedAt': '2025-11-18T00:55:36.652Z',
#    'createdAt': '2025-11-14T23:10:16.835Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 158,
#    'datetime': '2025-11-17T01:00:00.000Z',
#    'updatedAt': '2025-11-18T01:55:12.912Z',
#    'createdAt': '2025-11-15T00:25:35.962Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 150,
#    'datetime': '2025-11-17T02:00:00.000Z',
#    'updatedAt': '2025-11-18T02:55:55.163Z',
#    'createdAt': '2025-11-15T00:39:44.767Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 142,
#    'datetime': '2025-11-17T03:00:00.000Z',
#    'updatedAt': '2025-11-18T03:55:50.855Z',
#    'createdAt': '2025-11-15T02:25:22.433Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 174,
#    'datetime': '2025-11-17T04:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:36.952Z',
#    'createdAt': '2025-11-15T03:26:15.915Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 188,
#    'datetime': '2025-11-17T05:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:20.892Z',
#    'createdAt': '2025-11-15T04:25:58.371Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 206,
#    'datetime': '2025-11-17T06:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:36.952Z',
#    'createdAt': '2025-11-15T05:25:07.443Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 218,
#    'datetime': '2025-11-17T07:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:36.952Z',
#    'createdAt': '2025-11-15T06:40:37.996Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 157,
#    'datetime': '2025-11-17T08:00:00.000Z',
#    'updatedAt': '2025-11-18T08:55:52.100Z',
#    'createdAt': '2025-11-15T07:25:58.230Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 103,
#    'datetime': '2025-11-17T09:00:00.000Z',
#    'updatedAt': '2025-11-18T09:55:39.030Z',
#    'createdAt': '2025-11-15T08:25:40.966Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 89,
#    'datetime': '2025-11-17T10:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:26.296Z',
#    'createdAt': '2025-11-15T09:40:03.311Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 101,
#    'datetime': '2025-11-17T11:00:00.000Z',
#    'updatedAt': '2025-11-18T11:55:32.193Z',
#    'createdAt': '2025-11-15T10:25:08.594Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 85,
#    'datetime': '2025-11-17T12:00:00.000Z',
#    'updatedAt': '2025-11-18T12:55:03.859Z',
#    'createdAt': '2025-11-15T11:40:46.477Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 83,
#    'datetime': '2025-11-17T13:00:00.000Z',
#    'updatedAt': '2025-11-18T13:55:26.421Z',
#    'createdAt': '2025-11-15T12:26:10.662Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 104,
#    'datetime': '2025-11-17T14:00:00.000Z',
#    'updatedAt': '2025-11-18T15:10:29.290Z',
#    'createdAt': '2025-11-15T13:42:54.043Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 120,
#    'datetime': '2025-11-17T15:00:00.000Z',
#    'updatedAt': '2025-11-18T16:11:33.270Z',
#    'createdAt': '2025-11-15T14:25:54.113Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 157,
#    'datetime': '2025-11-17T16:00:00.000Z',
#    'updatedAt': '2025-11-18T17:10:32.039Z',
#    'createdAt': '2025-11-15T15:40:54.893Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 180,
#    'datetime': '2025-11-17T17:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:27.080Z',
#    'createdAt': '2025-11-15T16:25:06.010Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 159,
#    'datetime': '2025-11-17T18:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:27.080Z',
#    'createdAt': '2025-11-15T17:26:06.994Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 216,
#    'datetime': '2025-11-17T19:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:40.993Z',
#    'createdAt': '2025-11-15T18:25:27.834Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 172,
#    'datetime': '2025-11-17T20:00:00.000Z',
#    'updatedAt': '2025-11-18T20:55:09.826Z',
#    'createdAt': '2025-11-15T19:25:26.222Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 129,
#    'datetime': '2025-11-17T21:00:00.000Z',
#    'updatedAt': '2025-11-18T21:55:39.312Z',
#    'createdAt': '2025-11-15T20:25:36.594Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 150,
#    'datetime': '2025-11-17T22:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:27.080Z',
#    'createdAt': '2025-11-15T21:25:02.777Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 121,
#    'datetime': '2025-11-17T23:00:00.000Z',
#    'updatedAt': '2025-11-18T13:40:30.415Z',
#    'createdAt': '2025-11-15T22:26:42.051Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 113,
#    'datetime': '2025-11-18T00:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:40.993Z',
#    'createdAt': '2025-11-15T23:25:58.694Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 149,
#    'datetime': '2025-11-18T01:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:27.080Z',
#    'createdAt': '2025-11-16T00:39:56.503Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 125,
#    'datetime': '2025-11-18T02:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:40.993Z',
#    'createdAt': '2025-11-16T00:40:09.881Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 152,
#    'datetime': '2025-11-18T03:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:40.993Z',
#    'createdAt': '2025-11-16T02:26:03.479Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 175,
#    'datetime': '2025-11-18T04:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:27.080Z',
#    'createdAt': '2025-11-16T03:26:18.863Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 122,
#    'datetime': '2025-11-18T05:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:27.080Z',
#    'createdAt': '2025-11-16T04:26:31.835Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 186,
#    'datetime': '2025-11-18T06:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:27.080Z',
#    'createdAt': '2025-11-16T05:25:51.611Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 206,
#    'datetime': '2025-11-18T07:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:40.993Z',
#    'createdAt': '2025-11-16T06:25:22.934Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 120,
#    'datetime': '2025-11-18T08:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:40.993Z',
#    'createdAt': '2025-11-16T07:25:17.073Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-18T09:00:00.000Z',
#    'updatedAt': '2025-11-18T11:11:43.566Z',
#    'createdAt': '2025-11-16T08:24:54.962Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 83,
#    'datetime': '2025-11-18T10:00:00.000Z',
#    'updatedAt': '2025-11-19T14:10:07.955Z',
#    'createdAt': '2025-11-16T09:25:42.176Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 89,
#    'datetime': '2025-11-18T11:00:00.000Z',
#    'updatedAt': '2025-11-18T12:40:16.616Z',
#    'createdAt': '2025-11-16T10:25:00.779Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 100,
#    'datetime': '2025-11-18T12:00:00.000Z',
#    'updatedAt': '2025-11-18T13:55:42.492Z',
#    'createdAt': '2025-11-16T11:42:03.054Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 94,
#    'datetime': '2025-11-18T13:00:00.000Z',
#    'updatedAt': '2025-11-18T15:10:43.905Z',
#    'createdAt': '2025-11-16T12:41:09.505Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 82,
#    'datetime': '2025-11-18T14:00:00.000Z',
#    'updatedAt': '2025-11-18T16:11:23.529Z',
#    'createdAt': '2025-11-16T13:25:34.212Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 130,
#    'datetime': '2025-11-18T15:00:00.000Z',
#    'updatedAt': '2025-11-19T13:25:27.080Z',
#    'createdAt': '2025-11-16T14:25:54.459Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 215,
#    'datetime': '2025-11-18T16:00:00.000Z',
#    'updatedAt': '2025-11-19T16:55:44.285Z',
#    'createdAt': '2025-11-16T15:26:28.960Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 242,
#    'datetime': '2025-11-18T17:00:00.000Z',
#    'updatedAt': '2025-11-19T17:55:28.246Z',
#    'createdAt': '2025-11-16T16:25:47.341Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'},
#   {'zone': 'ES',
#    'carbonIntensity': 173,
#    'datetime': '2025-11-18T18:00:00.000Z',
#    'updatedAt': '2025-11-19T19:10:09.385Z',
#    'createdAt': '2025-11-16T17:26:27.687Z',
#    'emissionFactorType': 'lifecycle',
#    'isEstimated': True,
#    'estimationMethod': 'TEST_MODE_DATA'}],
#  'temporalGranularity': 'hourly',
#  '_disclaimer': 'TEST MODE: intentionally inaccurate data for integration testing. For live data, head over to https://portal.electricitymaps.com/ and request access.'}

# %%
#extract the timestamps and values to create a dataframe
data_json = response.json()
data_points = data_json['data']
timestamps = []
values = []
for point in data_points:
    timestamps.append(point['datetime'])
    values.append(point['carbonIntensity'])
import pandas as pd
df = pd.DataFrame({'Timestamp': timestamps, 'Carbon Intensity': values})
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df
# Out:
#                     Timestamp  Carbon Intensity
# 0   2025-11-09 17:00:00+00:00               172
# 1   2025-11-09 18:00:00+00:00               201
# 2   2025-11-09 19:00:00+00:00               175
# 3   2025-11-09 20:00:00+00:00               225
# 4   2025-11-09 21:00:00+00:00               191
# ..                        ...               ...
# 213 2025-11-18 14:00:00+00:00                82
# 214 2025-11-18 15:00:00+00:00               130
# 215 2025-11-18 16:00:00+00:00               215
# 216 2025-11-18 17:00:00+00:00               242
# 217 2025-11-18 18:00:00+00:00               173
#
# [218 rows x 2 columns]

# %% [markdown]
# Looking both at the docs and at the json structure we can see we have 2 information available **carbon intensity** and **fossil fuel percentage** for the desired country at the latest time available.

# %% [markdown]
# # Part IV: WeatherAPI.com

# %% [markdown]
# WeatherAPI.com is a powerful fully managed **free weather and geolocation API provider** that provides extensive APIs that range from the weather forecast, historical weather, future weather, weather alerts, air quality data, IP lookup, and astronomy through to sports, time zone, and geolocation.
#
# The API can be found accessed in the popular API market place **RapidAPI** (https://rapidapi.com/weatherapi/api/weatherapi-com)
#
# It is required to sign up with an account in RapidAPI to use the free API. When you did that you need to subscribe to a pricing plan for the API (the free one, of course). Take a look at the limited functionalities, you can access only a few endpoints. As you can see all of them allow for **GET** methods.
#
# Once the subscription is active you can generate in an authomatic way the code for the request through the interface (very useful) and copypaste it to use it right away.
#
# One of the endpoints available with the free subscription is the current weather. Let's check this out

# %%
import requests

# chose the endpoint
url = "https://weatherapi-com.p.rapidapi.com/current.json"

# define the headers with the authorization token
headers = {"X-RapidAPI-Key": "6a425b2a7bmshc1f059e65b98fb7p1cdd78jsn184965114ca2",
           "X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"}

# define parameters as specified in the API documentation
querystring = {"q":"Barcelona","dt":"2022-12-25"}

#create the get request
response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"location":{"name":"Barcelona","region":"Catalonia","country":"Spain","lat":41.3833,"lon":2.1833,"tz_id":"Europe/Madrid","localtime_epoch":1763579601,"localtime":"2025-11-19 20:13"},"current":{"last_updated_epoch":1763578800,"last_updated":"2025-11-19 20:00","temp_c":9.1,"temp_f":48.4,"is_day":0,"condition":{"text":"Clear","icon":"//cdn.weatherapi.com/weather/64x64/night/113.png","code":1000},"wind_mph":9.6,"wind_kph":15.5,"wind_degree":308,"wind_dir":"NW","pressure_mb":1013.0,"pressure_in":29.91,"precip_mm":0.0,"precip_in":0.0,"humidity":62,"cloud":0,"feelslike_c":6.7,"feelslike_f":44.1,"windchill_c":10.2,"windchill_f":50.4,"heatindex_c":11.9,"heatindex_f":53.5,"dewpoint_c":1.4,"dewpoint_f":34.5,"vis_km":10.0,"vis_miles":6.0,"uv":0.0,"gust_mph":11.7,"gust_kph":18.9}}

# %% [markdown]
# You can now go on with the data extraction and post-processing of streaming data as you like

# %%
data_json = response.json()

# %%
location = data_json['location']['name']
location
# Out:
# 'Barcelona'

# %%
temp_c = data_json['current']['temp_c']
temp_c
# Out:
# 9.1

# %%
wind_kph = data_json['current']['wind_kph']
wind_kph
# Out:
# 15.5

# %% [markdown]
# # Part V: Electricity Map free API

# %% [markdown]
# Go to the website https://api-portal.electricitymaps.com/ and sign up with your account of preference. Confirm your email and validate your account, then go to the Getting Started section and choose the product plan option **Free Tier**. Subscrive to the free plan.
#
# In your personal account on the API portal you need to access the *Product Catalog* and enter the *Personal Free Tier* product. Once inside, you will find yourself into the actual API Client of the free tier product. Here you can find the documentation, specyifing the endpoints and your personal API key generator (Blobr API Keys). You can also keep en eye on your requests history.

# %% [markdown]
# You can also check if the API service is UP and running by making a simple GET request on the dedicated endpoint. This instruction is available in the API documentation under "Health" route.

# %%
# check if API is up
health_endpoint = 'https://api.electricitymap.org/health'
# NB: this is an endpoint available withing the paid API service but you can use it without token to test the connection

# make a small get request (no token required)
response = requests.get(health_endpoint)
response

status = response.status_code

# check the status code
if status < 200:
    print('informational')
    # If the status code is 200, treat the information.
elif status >= 200 and status < 300:
    print('Connection is established. API is UP!')
    #okBehavior(response) # runs the function to get list of archives
elif status >= 300 and status < 400:
    print('redirection')
elif status >= 400 and status < 500:
    print('client error')
else:
    print('server error')
# Out:
# Connection is established. API is UP!

# %% [markdown]
# ### Check available zones

# %% [markdown]
# Each token (you can use the primary token) has some zones that can be accessed, for which data are available. An endpoint is available to return all zones available if no auth-token is provided.

# %%
#my_token = 'tYmqsdm22FbSg2RMasqWN1PiZOs9Mwgk' # replace with your personal API key
my_token = 'jkG9yQHIscL1a'
my_token = 'H2xDenu3HBrIn'

# %%
# check for available zones
base_prod_url = "https://api.electricitymap.org/v3/zones"

# make request (this request works with no token
response = requests.get(base_prod_url)
response
# Out:
# <Response [200]>

# %%
data_dict = response.json()

print("Country name:")
# Extract abbreviation and name of each country
for abbreviation, country_info in data_dict.items():
    country_name = country_info["zoneName"]
    print(f" {country_name}, {abbreviation}")
# Out:
# Country name:
#  United Arab Emirates, AE
#  Afghanistan, AF
#  Antigua and Barbuda, AG
#  Albania, AL
#  Armenia, AM
#  Angola, AO
#  Argentina, AR
#  Austria, AT
#  Australia, AU
#  New South Wales, AU-NSW
#  Northern Territory, AU-NT
#  Queensland, AU-QLD
#  South Australia, AU-SA
#  Tasmania, AU-TAS
#  Flinders Island, AU-TAS-FI
#  King Island, AU-TAS-KI
#  Victoria, AU-VIC
#  Western Australia, AU-WA
#  Rottnest Island, AU-WA-RI
#  Aruba, AW
#  Åland Islands, AX
#  Azerbaijan, AZ
#  Bosnia and Herzegovina, BA
#  Barbados, BB
#  Bangladesh, BD
#  Belgium, BE
#  Burkina Faso, BF
#  Bulgaria, BG
#  Bahrain, BH
#  Burundi, BI
#  Benin, BJ
#  Brunei, BN
#  Bolivia, BO
#  Brazil, BR
#  Central Brazil, BR-CS
#  North Brazil, BR-N
#  North-East Brazil, BR-NE
#  South Brazil, BR-S
#  Bahamas, BS
#  Bhutan, BT
#  Botswana, BW
#  Belarus, BY
#  Belize, BZ
#  Canada, CA
#  Alberta, CA-AB
#  British Columbia, CA-BC
#  Manitoba, CA-MB
#  New Brunswick, CA-NB
#  Newfoundland and Labrador, CA-NL
#  Nova Scotia, CA-NS
#  Northwest Territories, CA-NT
#  Nunavut, CA-NU
#  Ontario, CA-ON
#  Prince Edward Island, CA-PE
#  Québec, CA-QC
#  Saskatchewan, CA-SK
#  Yukon, CA-YT
#  Democratic Republic of the Congo, CD
#  Central African Republic, CF
#  Congo, CG
#  Switzerland, CH
#  Ivory Coast, CI
#  Sistema Eléctrico Nacional, CL-SEN
#  Cameroon, CM
#  China, CN
#  Colombia, CO
#  Costa Rica, CR
#  Cuba, CU
#  Cabo Verde, CV
#  Curaçao, CW
#  Cyprus, CY
#  Czechia, CZ
#  Germany, DE
#  Djibouti, DJ
#  Denmark, DK
#  Bornholm, DK-BHM
#  West Denmark, DK-DK1
#  East Denmark, DK-DK2
#  Dominica, DM
#  Dominican Republic, DO
#  Algeria, DZ
#  Ecuador, EC
#  Estonia, EE
#  Egypt, EG
#  Eritrea, ER
#  Spain, ES
#  Ceuta, ES-CE
#  Fuerteventura, ES-CN-FV
#  Gran Canaria, ES-CN-GC
#  El Hierro, ES-CN-HI
#  Isla de la Gomera, ES-CN-IG
#  La Palma, ES-CN-LP
#  Lanzarote, ES-CN-LZ
#  Tenerife, ES-CN-TE
#  Formentera, ES-IB-FO
#  Ibiza, ES-IB-IZ
#  Mallorca, ES-IB-MA
#  Menorca, ES-IB-ME
#  Melilla, ES-ML
#  Ethiopia, ET
#  Finland, FI
#  Fiji, FJ
#  Falkland Islands, FK
#  Micronesia, FM
#  Faroe Islands, FO
#  Main Islands, FO-MI
#  South Island, FO-SI
#  France, FR
#  Corsica, FR-COR
#  Gabon, GA
#  Great Britain, GB
#  Northern Ireland, GB-NIR
#  Orkney Islands, GB-ORK
#  Georgia, GE
#  French Guiana, GF
#  Ghana, GH
#  Gibraltar, GI
#  Greenland, GL
#  Gambia, GM
#  Guinea, GN
#  Guadeloupe, GP
#  Equatorial Guinea, GQ
#  Greece, GR
#  South Georgia and the South Sandwich Islands, GS
#  Guatemala, GT
#  Guam, GU
#  Guinea-Bissau, GW
#  Guyana, GY
#  Hong Kong, HK
#  Honduras, HN
#  Croatia, HR
#  Haiti, HT
#  Hungary, HU
#  Indonesia, ID
#  Ireland, IE
#  Israel, IL
#  Mainland India, IN
#  Eastern India, IN-EA
#  North Eastern India, IN-NE
#  Northern India, IN-NO
#  Southern India, IN-SO
#  Western India, IN-WE
#  Iraq, IQ
#  Iran, IR
#  Iceland, IS
#  Italy, IT
#  Central North Italy, IT-CNO
#  Central South Italy, IT-CSO
#  North Italy, IT-NO
#  Sardinia, IT-SAR
#  Sicily, IT-SIC
#  South Italy, IT-SO
#  Jamaica, JM
#  Jordan, JO
#  Japan, JP
#  Chūbu, JP-CB
#  Chūgoku, JP-CG
#  Hokkaidō, JP-HKD
#  Hokuriku, JP-HR
#  Kansai, JP-KN
#  Kyūshū, JP-KY
#  Okinawa, JP-ON
#  Shikoku, JP-SK
#  Tōhoku, JP-TH
#  Tōkyō, JP-TK
#  Kenya, KE
#  Kyrgyzstan, KG
#  Cambodia, KH
#  Comoros, KM
#  North Korea, KP
#  South Korea, KR
#  Kuwait, KW
#  Cayman Islands, KY
#  Kazakhstan, KZ
#  Laos, LA
#  Lebanon, LB
#  Saint Lucia, LC
#  Sri Lanka, LK
#  Liberia, LR
#  Lesotho, LS
#  Lithuania, LT
#  Luxembourg, LU
#  Latvia, LV
#  Libya, LY
#  Morocco, MA
#  Moldova, MD
#  Montenegro, ME
#  Madagascar, MG
#  North Macedonia, MK
#  Mali, ML
#  Myanmar, MM
#  Mongolia, MN
#  Macao, MO
#  Martinique, MQ
#  Mauritania, MR
#  Malta, MT
#  Mauritius, MU
#  Maldives, MV
#  Malawi, MW
#  Mexico, MX
#  Malaysia, MY
#  Borneo, MY-EM
#  Peninsula, MY-WM
#  Mozambique, MZ
#  Namibia, NA
#  New Caledonia, NC
#  Niger, NE
#  Nigeria, NG
#  Nicaragua, NI
#  Netherlands, NL
#  Norway, NO
#  Southeast Norway, NO-NO1
#  Southwest Norway, NO-NO2
#  Middle Norway, NO-NO3
#  North Norway, NO-NO4
#  West Norway, NO-NO5
#  Nepal, NP
#  New Zealand, NZ
#  Oman, OM
#  Panama, PA
#  Peru, PE
#  French Polynesia, PF
#  Papua New Guinea, PG
#  Philippines, PH
#  Luzon, PH-LU
#  Mindanao, PH-MI
#  Visayas, PH-VI
#  Pakistan, PK
#  Poland, PL
#  Saint Pierre and Miquelon, PM
#  Puerto Rico, PR
#  State of Palestine, PS
#  Portugal, PT
#  Madeira, PT-MA
#  Palau, PW
#  Paraguay, PY
#  Qatar, QA
#  Réunion, RE
#  Romania, RO
#  Serbia, RS
#  Europe-Ural, RU-1
#  Siberia, RU-2
#  East, RU-AS
#  Rwanda, RW
#  Saudi Arabia, SA
#  Solomon Islands, SB
#  Seychelles, SC
#  Sudan, SD
#  Sweden, SE
#  North Sweden, SE-SE1
#  North Central Sweden, SE-SE2
#  South Central Sweden, SE-SE3
#  South Sweden, SE-SE4
#  Singapore, SG
#  Slovenia, SI
#  Slovakia, SK
#  Sierra Leone, SL
#  Senegal, SN
#  Somalia, SO
#  Suriname, SR
#  South Sudan, SS
#  São Tomé and Príncipe, ST
#  El Salvador, SV
#  Syria, SY
#  Eswatini, SZ
#  Chad, TD
#  Togo, TG
#  Thailand, TH
#  Tajikistan, TJ
#  Timor-Leste, TL
#  Turkmenistan, TM
#  Tunisia, TN
#  Tonga, TO
#  Turkey, TR
#  Trinidad and Tobago, TT
#  Taiwan, TW
#  Tanzania, TZ
#  Uganda, UG
#  United States, US
#  Alaska, US-AK
#  Southeast Alaska Power Agency, US-AK-SEAPA
#  Balancing Authority of Northern California, US-CAL-BANC
#  CAISO, US-CAL-CISO
#  Imperial Irrigation District, US-CAL-IID
#  Los Angeles Department of Water and Power, US-CAL-LDWP
#  Turlock Irrigation District, US-CAL-TIDC
#  Duke Energy Progress East, US-CAR-CPLE
#  Duke Energy Progress West, US-CAR-CPLW
#  Duke Energy Carolinas, US-CAR-DUK
#  South Carolina Public Service Authority, US-CAR-SC
#  South Carolina Electric & Gas Company, US-CAR-SCEG
#  Alcoa Power Generating, Inc. Yadkin Division, US-CAR-YAD
#  Southwestern Power Administration, US-CENT-SPA
#  Southwest Power Pool, US-CENT-SWPP
#  Florida Municipal Power Pool, US-FLA-FMPP
#  Duke Energy Florida, US-FLA-FPC
#  Florida Power and Light Company, US-FLA-FPL
#  Gainesville Regional Utilities, US-FLA-GVL
#  City of Homestead, US-FLA-HST
#  Jacksonville Electric Authority, US-FLA-JEA
#  Seminole Electric Cooperative, US-FLA-SEC
#  City of Tallahassee, US-FLA-TAL
#  Tampa Electric Company, US-FLA-TEC
#  Hawaii, US-HI
#  PJM Interconnection, US-MIDA-PJM
#  Associated Electric Cooperative, US-MIDW-AECI
#  Louisville Gas and Electric Company and Kentucky Utilities, US-MIDW-LGEE
#  Midcontinent ISO, US-MIDW-MISO
#  ISO New England, US-NE-ISNE
#  Avista Corporation, US-NW-AVA
#  Bonneville Power Administration, US-NW-BPAT
#  Chelan County, US-NW-CHPD
#  Douglas County, US-NW-DOPD
#  Grant County, US-NW-GCPD
#  Gridforce Energy Management, US-NW-GRID
#  Idaho Power Company, US-NW-IPCO
#  Nevada Power Company, US-NW-NEVP
#  Northwestern Energy, US-NW-NWMT
#  Pacificorp East, US-NW-PACE
#  Pacificorp West, US-NW-PACW
#  Portland General Electric Company, US-NW-PGE
#  Public Service Company of Colorado, US-NW-PSCO
#  Puget Sound Energy, US-NW-PSEI
#  Seattle City Light, US-NW-SCL
#  City of Tacoma, US-NW-TPWR
#  Western Area Power Administration - Rocky Mountain Region, US-NW-WACM
#  Western Area Power Administration - Upper Great Plains West, US-NW-WAUW
#  New York ISO, US-NY-NYIS
#  Southeastern Power Administration, US-SE-SEPA
#  Southern Company Services, US-SE-SOCO
#  Arizona Public Service Company, US-SW-AZPS
#  El Paso Electric Company, US-SW-EPE
#  Public Service Company of New Mexico, US-SW-PNM
#  Salt River Project, US-SW-SRP
#  Tucson Electric Power Company, US-SW-TEPC
#  Western Area Power Administration - Desert Southwest Region, US-SW-WALC
#  Tennessee Valley Authority, US-TEN-TVA
#  Electric Reliability Council of Texas, US-TEX-ERCO
#  Uruguay, UY
#  Uzbekistan, UZ
#  Saint Vincent and the Grenadines, VC
#  Venezuela, VE
#  Virgin Islands, VI
#  Vietnam, VN
#  Vanuatu, VU
#  Samoa, WS
#  Kosovo, XK
#  Yemen, YE
#  Mayotte, YT
#  South Africa, ZA
#  Zambia, ZM
#  Zimbabwe, ZW

# %% [markdown]
# ### Live Power Breakdown

# %% [markdown]
# Checking the API documentation different endpoints can be found to gather different type of data. For each of them, the possible HTTP requests are listed. Methods are almost always **GET** to stream the data.
# Let's have a look at the *live power breakdown*.

# %%
live_power_endpoint = "https://api.electricitymap.org/v3/power-breakdown/history"

# %% [markdown]
# The header section is always used for the authorization token (in this case).

# %%
headers = {'auth-token': my_token}

# %% [markdown]
# Parameters to be specified are listed in the documentation.

# %%
params = {'zone': "IT"}

# %% [markdown]
# Let's create the request and extract the data

# %%
response = requests.get(live_power_endpoint, headers=headers, params=params)
response.text
# Out:
# '{"zone":"IT","history":[{"zone":"IT","datetime":"2025-11-18T20:00:00.000Z","updatedAt":"2025-11-19T14:10:07.955Z","createdAt":"2025-11-16T19:41:30.590Z","powerConsumptionBreakdown":{"nuclear":3097,"geothermal":610,"biomass":768,"coal":935,"wind":2409,"solar":2,"hydro":4322,"gas":17068,"oil":59,"unknown":2518,"hydro discharge":205,"battery discharge":4},"powerProductionBreakdown":{"nuclear":null,"geothermal":610,"biomass":685,"coal":792,"wind":1792,"solar":0,"hydro":2739,"gas":16754,"oil":11,"unknown":2474,"hydro discharge":24,"battery discharge":-36},"powerImportBreakdown":{"AT":146,"CH":1476,"FR":3389,"GR":315,"ME":258,"MT":0,"SI":810,"FR-COR":0},"powerExportBreakdown":{"AT":0,"CH":0,"FR":0,"GR":0,"ME":0,"MT":143,"SI":0,"FR-COR":99},"fossilFreePercentage":36,"renewablePercentage":26,"powerConsumptionTotal":31996,"powerProductionTotal":25880,"powerImportTotal":6394,"powerExportTotal":242,"isEstimated":false,"estimationMethod":null},{"zone":"IT","datetime":"2025-11-18T21:00:00.000Z","updatedAt":"2025-11-19T16:10:00.282Z","createdAt":"2025-11-16T20:26:34.077Z","powerConsumptionBreakdown":{"nuclear":2966,"geothermal":598,"biomass":782,"coal":1060,"wind":2605,"solar":1,"hydro":4112,"gas":14584,"oil":58,"unknown":2258,"hydro discharge":128,"battery discharge":1},"powerProductionBreakdown":{"nuclear":null,"geothermal":598,"biomass":691,"coal":865,"wind":1898,"solar":0,"hydro":2479,"gas":14157,"oil":11,"unknown":2214,"hydro discharge":-5,"battery discharge":-35},"powerImportBreakdown":{"AT":143,"CH":1307,"FR":3183,"GR":466,"ME":501,"MT":0,"SI":913,"FR-COR":0},"powerExportBreakdown":{"AT":0,"CH":0,"FR":0,"GR":0,"ME":0,"MT":135,"SI":0,"FR-COR":98},"fossilFreePercentage":39,"renewablePercentage":28,"powerConsumptionTotal":29152,"powerProductionTotal":22913,"powerImportTotal":6513,"powerExportTotal":232,"isEstimated":false,"estimationMethod":null},{"zone":"IT","datetime":"2025-11-18T22:00:00.000Z","updatedAt":"2025-11-19T16:10:00.282Z","createdAt":"2025-11-16T21:26:53.839Z","powerConsumptionBreakdown":{"nuclear":3034,"geothermal":612,"biomass":821,"coal":1116,"wind":2987,"solar":1,"hydro":3997,"gas":12298,"oil":51,"unknown":2015,"hydro discharge":87,"battery discharge":1},"powerProductionBreakdown":{"nuclear":null,"geothermal":612,"biomass":722,"coal":877,"wind":2218,"solar":0,"hydro":2267,"gas":11923,"oil":11,"unknown":1979,"hydro discharge":-6,"battery discharge":-247},"powerImportBreakdown":{"AT":139,"CH":1636,"FR":3033,"GR":492,"ME":588,"MT":0,"SI":984,"FR-COR":0},"powerExportBreakdown":{"AT":0,"CH":0,"FR":0,"GR":0,"ME":0,"MT":103,"SI":0,"FR-COR":102},"fossilFreePercentage":43,"renewablePercentage":32,"powerConsumptionTotal":27021,"powerProductionTotal":20609,"powerImportTotal":6871,"powerExportTotal":205,"isEstimated":false,"estimationMethod":null},{"zone":"IT","datetime":"2025-11-18T23:00:00.000Z","updatedAt":"2025-11-19T18:41:33.245Z","createdAt":"2025-11-16T22:40:27.004Z","powerConsumptionBreakdown":{"nuclear":2696,"geothermal":606,"biomass":625,"coal":978,"wind":2094,"solar":1,"hydro":3470,"gas":11521,"oil":41,"unknown":1775,"hydro discharge":58,"battery discharge":0},"powerProductionBreakdown":{"nuclear":null,"geothermal":615,"biomass":559,"coal":803,"wind":1361,"solar":0,"hydro":2262,"gas":11521,"oil":12,"unknown":1821,"hydro discharge":-347,"battery discharge":-687},"powerImportBreakdown":{"AT":137,"CH":1066,"FR":2956,"GR":499,"ME":598,"MT":0,"SI":852,"FR-COR":0},"powerExportBreakdown":{"AT":0,"CH":0,"FR":0,"GR":0,"ME":0,"MT":83,"SI":0,"FR-COR":82},"fossilFreePercentage":40,"renewablePercentage":29,"powerConsumptionTotal":23863,"powerProductionTotal":18954,"powerImportTotal":6108,"powerExportTotal":165,"isEstimated":false,"estimationMethod":null},{"zone":"IT","datetime":"2025-11-19T00:00:00.000Z","updatedAt":"2025-11-19T18:41:33.245Z","createdAt":"2025-11-16T23:25:25.723Z","powerConsumptionBreakdown":{"nuclear":2785,"geothermal":614,"biomass":746,"coal":921,"wind":2840,"solar":1,"hydro":3487,"gas":10532,"oil":47,"unknown":17 ...

# %% [markdown]
# Let's extract the data and try to visualize

# %%
hystorical_data = response.json()["history"]
hystorical_data
# Out:
# [{'zone': 'IT',
#   'datetime': '2025-11-18T20:00:00.000Z',
#   'updatedAt': '2025-11-19T14:10:07.955Z',
#   'createdAt': '2025-11-16T19:41:30.590Z',
#   'powerConsumptionBreakdown': {'nuclear': 3097,
#    'geothermal': 610,
#    'biomass': 768,
#    'coal': 935,
#    'wind': 2409,
#    'solar': 2,
#    'hydro': 4322,
#    'gas': 17068,
#    'oil': 59,
#    'unknown': 2518,
#    'hydro discharge': 205,
#    'battery discharge': 4},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 610,
#    'biomass': 685,
#    'coal': 792,
#    'wind': 1792,
#    'solar': 0,
#    'hydro': 2739,
#    'gas': 16754,
#    'oil': 11,
#    'unknown': 2474,
#    'hydro discharge': 24,
#    'battery discharge': -36},
#   'powerImportBreakdown': {'AT': 146,
#    'CH': 1476,
#    'FR': 3389,
#    'GR': 315,
#    'ME': 258,
#    'MT': 0,
#    'SI': 810,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 143,
#    'SI': 0,
#    'FR-COR': 99},
#   'fossilFreePercentage': 36,
#   'renewablePercentage': 26,
#   'powerConsumptionTotal': 31996,
#   'powerProductionTotal': 25880,
#   'powerImportTotal': 6394,
#   'powerExportTotal': 242,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-18T21:00:00.000Z',
#   'updatedAt': '2025-11-19T16:10:00.282Z',
#   'createdAt': '2025-11-16T20:26:34.077Z',
#   'powerConsumptionBreakdown': {'nuclear': 2966,
#    'geothermal': 598,
#    'biomass': 782,
#    'coal': 1060,
#    'wind': 2605,
#    'solar': 1,
#    'hydro': 4112,
#    'gas': 14584,
#    'oil': 58,
#    'unknown': 2258,
#    'hydro discharge': 128,
#    'battery discharge': 1},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 598,
#    'biomass': 691,
#    'coal': 865,
#    'wind': 1898,
#    'solar': 0,
#    'hydro': 2479,
#    'gas': 14157,
#    'oil': 11,
#    'unknown': 2214,
#    'hydro discharge': -5,
#    'battery discharge': -35},
#   'powerImportBreakdown': {'AT': 143,
#    'CH': 1307,
#    'FR': 3183,
#    'GR': 466,
#    'ME': 501,
#    'MT': 0,
#    'SI': 913,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 135,
#    'SI': 0,
#    'FR-COR': 98},
#   'fossilFreePercentage': 39,
#   'renewablePercentage': 28,
#   'powerConsumptionTotal': 29152,
#   'powerProductionTotal': 22913,
#   'powerImportTotal': 6513,
#   'powerExportTotal': 232,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-18T22:00:00.000Z',
#   'updatedAt': '2025-11-19T16:10:00.282Z',
#   'createdAt': '2025-11-16T21:26:53.839Z',
#   'powerConsumptionBreakdown': {'nuclear': 3034,
#    'geothermal': 612,
#    'biomass': 821,
#    'coal': 1116,
#    'wind': 2987,
#    'solar': 1,
#    'hydro': 3997,
#    'gas': 12298,
#    'oil': 51,
#    'unknown': 2015,
#    'hydro discharge': 87,
#    'battery discharge': 1},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 612,
#    'biomass': 722,
#    'coal': 877,
#    'wind': 2218,
#    'solar': 0,
#    'hydro': 2267,
#    'gas': 11923,
#    'oil': 11,
#    'unknown': 1979,
#    'hydro discharge': -6,
#    'battery discharge': -247},
#   'powerImportBreakdown': {'AT': 139,
#    'CH': 1636,
#    'FR': 3033,
#    'GR': 492,
#    'ME': 588,
#    'MT': 0,
#    'SI': 984,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 103,
#    'SI': 0,
#    'FR-COR': 102},
#   'fossilFreePercentage': 43,
#   'renewablePercentage': 32,
#   'powerConsumptionTotal': 27021,
#   'powerProductionTotal': 20609,
#   'powerImportTotal': 6871,
#   'powerExportTotal': 205,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-18T23:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:33.245Z',
#   'createdAt': '2025-11-16T22:40:27.004Z',
#   'powerConsumptionBreakdown': {'nuclear': 2696,
#    'geothermal': 606,
#    'biomass': 625,
#    'coal': 978,
#    'wind': 2094,
#    'solar': 1,
#    'hydro': 3470,
#    'gas': 11521,
#    'oil': 41,
#    'unknown': 1775,
#    'hydro discharge': 58,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 615,
#    'biomass': 559,
#    'coal': 803,
#    'wind': 1361,
#    'solar': 0,
#    'hydro': 2262,
#    'gas': 11521,
#    'oil': 12,
#    'unknown': 1821,
#    'hydro discharge': -347,
#    'battery discharge': -687},
#   'powerImportBreakdown': {'AT': 137,
#    'CH': 1066,
#    'FR': 2956,
#    'GR': 499,
#    'ME': 598,
#    'MT': 0,
#    'SI': 852,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 83,
#    'SI': 0,
#    'FR-COR': 82},
#   'fossilFreePercentage': 40,
#   'renewablePercentage': 29,
#   'powerConsumptionTotal': 23863,
#   'powerProductionTotal': 18954,
#   'powerImportTotal': 6108,
#   'powerExportTotal': 165,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T00:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:33.245Z',
#   'createdAt': '2025-11-16T23:25:25.723Z',
#   'powerConsumptionBreakdown': {'nuclear': 2785,
#    'geothermal': 614,
#    'biomass': 746,
#    'coal': 921,
#    'wind': 2840,
#    'solar': 1,
#    'hydro': 3487,
#    'gas': 10532,
#    'oil': 47,
#    'unknown': 1739,
#    'hydro discharge': 24,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 615,
#    'biomass': 675,
#    'coal': 713,
#    'wind': 2091,
#    'solar': 0,
#    'hydro': 2222,
#    'gas': 10374,
#    'oil': 12,
#    'unknown': 1741,
#    'hydro discharge': -429,
#    'battery discharge': -344},
#   'powerImportBreakdown': {'AT': 152,
#    'CH': 1162,
#    'FR': 2784,
#    'GR': 499,
#    'ME': 598,
#    'MT': 0,
#    'SI': 1017,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 69,
#    'SI': 0,
#    'FR-COR': 77},
#   'fossilFreePercentage': 44,
#   'renewablePercentage': 33,
#   'powerConsumptionTotal': 23736,
#   'powerProductionTotal': 18443,
#   'powerImportTotal': 6212,
#   'powerExportTotal': 146,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T01:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T00:26:01.090Z',
#   'powerConsumptionBreakdown': {'nuclear': 2740,
#    'geothermal': 610,
#    'biomass': 718,
#    'coal': 877,
#    'wind': 2790,
#    'solar': 1,
#    'hydro': 3343,
#    'gas': 9961,
#    'oil': 43,
#    'unknown': 1684,
#    'hydro discharge': 17,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 615,
#    'biomass': 668,
#    'coal': 710,
#    'wind': 2074,
#    'solar': 0,
#    'hydro': 2148,
#    'gas': 10067,
#    'oil': 12,
#    'unknown': 1716,
#    'hydro discharge': -392,
#    'battery discharge': -947},
#   'powerImportBreakdown': {'AT': 145,
#    'CH': 1357,
#    'FR': 2666,
#    'GR': 498,
#    'ME': 598,
#    'MT': 0,
#    'SI': 994,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 61,
#    'SI': 0,
#    'FR-COR': 86},
#   'fossilFreePercentage': 45,
#   'renewablePercentage': 33,
#   'powerConsumptionTotal': 22784,
#   'powerProductionTotal': 18011,
#   'powerImportTotal': 6259,
#   'powerExportTotal': 147,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T02:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:46.714Z',
#   'createdAt': '2025-11-17T00:40:10.867Z',
#   'powerConsumptionBreakdown': {'nuclear': 2742,
#    'geothermal': 610,
#    'biomass': 727,
#    'coal': 842,
#    'wind': 2767,
#    'solar': 1,
#    'hydro': 3217,
#    'gas': 10044,
#    'oil': 42,
#    'unknown': 1806,
#    'hydro discharge': 17,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 615,
#    'biomass': 683,
#    'coal': 710,
#    'wind': 2033,
#    'solar': 0,
#    'hydro': 2041,
#    'gas': 10199,
#    'oil': 12,
#    'unknown': 1848,
#    'hydro discharge': -342,
#    'battery discharge': -1022},
#   'powerImportBreakdown': {'AT': 132,
#    'CH': 1412,
#    'FR': 2683,
#    'GR': 499,
#    'ME': 598,
#    'MT': 0,
#    'SI': 855,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 61,
#    'SI': 0,
#    'FR-COR': 81},
#   'fossilFreePercentage': 44,
#   'renewablePercentage': 32,
#   'powerConsumptionTotal': 22815,
#   'powerProductionTotal': 18141,
#   'powerImportTotal': 6179,
#   'powerExportTotal': 142,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T03:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:46.714Z',
#   'createdAt': '2025-11-17T02:26:39.773Z',
#   'powerConsumptionBreakdown': {'nuclear': 2738,
#    'geothermal': 612,
#    'biomass': 747,
#    'coal': 874,
#    'wind': 2734,
#    'solar': 1,
#    'hydro': 3330,
#    'gas': 10766,
#    'oil': 32,
#    'unknown': 1903,
#    'hydro discharge': 18,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 615,
#    'biomass': 691,
#    'coal': 670,
#    'wind': 1949,
#    'solar': 0,
#    'hydro': 2077,
#    'gas': 10795,
#    'oil': 12,
#    'unknown': 1933,
#    'hydro discharge': -525,
#    'battery discharge': -560},
#   'powerImportBreakdown': {'AT': 144,
#    'CH': 1488,
#    'FR': 2657,
#    'GR': 498,
#    'ME': 597,
#    'MT': 0,
#    'SI': 863,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 67,
#    'SI': 0,
#    'FR-COR': 79},
#   'fossilFreePercentage': 43,
#   'renewablePercentage': 32,
#   'powerConsumptionTotal': 23755,
#   'powerProductionTotal': 18740,
#   'powerImportTotal': 6246,
#   'powerExportTotal': 147,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T04:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T03:41:58.319Z',
#   'powerConsumptionBreakdown': {'nuclear': 2498,
#    'geothermal': 615,
#    'biomass': 738,
#    'coal': 879,
#    'wind': 2556,
#    'solar': 8,
#    'hydro': 3473,
#    'gas': 12961,
#    'oil': 40,
#    'unknown': 2082,
#    'hydro discharge': 107,
#    'battery discharge': 1},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 615,
#    'biomass': 679,
#    'coal': 670,
#    'wind': 1830,
#    'solar': 0,
#    'hydro': 2327,
#    'gas': 12778,
#    'oil': 12,
#    'unknown': 2072,
#    'hydro discharge': -51,
#    'battery discharge': -252},
#   'powerImportBreakdown': {'AT': 137,
#    'CH': 1008,
#    'FR': 2617,
#    'GR': 496,
#    'ME': 515,
#    'MT': 0,
#    'SI': 680,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 90,
#    'SI': 0,
#    'FR-COR': 85},
#   'fossilFreePercentage': 39,
#   'renewablePercentage': 29,
#   'powerConsumptionTotal': 25957,
#   'powerProductionTotal': 20983,
#   'powerImportTotal': 5452,
#   'powerExportTotal': 175,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T05:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:46.714Z',
#   'createdAt': '2025-11-17T04:26:25.292Z',
#   'powerConsumptionBreakdown': {'nuclear': 2557,
#    'geothermal': 615,
#    'biomass': 727,
#    'coal': 764,
#    'wind': 2441,
#    'solar': 119,
#    'hydro': 3751,
#    'gas': 16379,
#    'oil': 41,
#    'unknown': 2575,
#    'hydro discharge': 109,
#    'battery discharge': 50},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 614,
#    'biomass': 671,
#    'coal': 684,
#    'wind': 1791,
#    'solar': 107,
#    'hydro': 2717,
#    'gas': 16181,
#    'oil': 12,
#    'unknown': 2518,
#    'hydro discharge': -43,
#    'battery discharge': 31},
#   'powerImportBreakdown': {'AT': 135,
#    'CH': 1448,
#    'FR': 2682,
#    'GR': 389,
#    'ME': 2,
#    'MT': 0,
#    'SI': 379,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 97,
#    'SI': 0,
#    'FR-COR': 92},
#   'fossilFreePercentage': 35,
#   'renewablePercentage': 26,
#   'powerConsumptionTotal': 30128,
#   'powerProductionTotal': 25326,
#   'powerImportTotal': 5035,
#   'powerExportTotal': 189,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T06:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T05:40:17.417Z',
#   'powerConsumptionBreakdown': {'nuclear': 2921,
#    'geothermal': 604,
#    'biomass': 730,
#    'coal': 812,
#    'wind': 2245,
#    'solar': 966,
#    'hydro': 5416,
#    'gas': 17866,
#    'oil': 38,
#    'unknown': 2878,
#    'hydro discharge': 389,
#    'battery discharge': 399},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 603,
#    'biomass': 674,
#    'coal': 761,
#    'wind': 1553,
#    'solar': 916,
#    'hydro': 3879,
#    'gas': 17552,
#    'oil': 12,
#    'unknown': 2777,
#    'hydro discharge': 170,
#    'battery discharge': 432},
#   'powerImportBreakdown': {'AT': 151,
#    'CH': 2217,
#    'FR': 3091,
#    'GR': 384,
#    'ME': 1,
#    'MT': 0,
#    'SI': 220,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 29,
#    'SI': 0,
#    'FR-COR': 98},
#   'fossilFreePercentage': 39,
#   'renewablePercentage': 31,
#   'powerConsumptionTotal': 35265,
#   'powerProductionTotal': 29329,
#   'powerImportTotal': 6063,
#   'powerExportTotal': 127,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T07:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T06:25:18.762Z',
#   'powerConsumptionBreakdown': {'nuclear': 2994,
#    'geothermal': 598,
#    'biomass': 739,
#    'coal': 839,
#    'wind': 2189,
#    'solar': 3579,
#    'hydro': 5775,
#    'gas': 17740,
#    'oil': 38,
#    'unknown': 2917,
#    'hydro discharge': 1097,
#    'battery discharge': 343},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 598,
#    'biomass': 674,
#    'coal': 754,
#    'wind': 1473,
#    'solar': 3410,
#    'hydro': 4015,
#    'gas': 17370,
#    'oil': 12,
#    'unknown': 2813,
#    'hydro discharge': 801,
#    'battery discharge': 354},
#   'powerImportBreakdown': {'AT': 138,
#    'CH': 2406,
#    'FR': 3259,
#    'GR': 430,
#    'ME': 1,
#    'MT': 0,
#    'SI': 461,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'ME': 0,
#    'MT': 25,
#    'SI': 0,
#    'FR-COR': 98},
#   'fossilFreePercentage': 45,
#   'renewablePercentage': 37,
#   'powerConsumptionTotal': 38847,
#   'powerProductionTotal': 32275,
#   'powerImportTotal': 6695,
#   'powerExportTotal': 123,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T08:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T07:25:44.311Z',
#   'powerConsumptionBreakdown': {'nuclear': 2965,
#    'geothermal': 597,
#    'biomass': 752,
#    'coal': 858,
#    'wind': 2238,
#    'solar': 6918,
#    'hydro': 4985,
#    'gas': 17098,
#    'oil': 38,
#    'unknown': 2930,
#    'hydro discharge': 294,
#    'battery discharge': 369},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 597,
#    'biomass': 683,
#    'coal': 741,
#    'wind': 1517,
#    'solar': 6486,
#    'hydro': 3287,
#    'gas': 16691,
#    'oil': 12,
#    'unknown': 2835,
#    'hydro discharge': 57,
#    'battery discharge': 357},
#   'powerImportBreakdown': {'AT': 140,
#    'CH': 2397,
#    'FR': 3205,
#    'GR': 499,
#    'MT': 0,
#    'SI': 667,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'MT': 38,
#    'SI': 0,
#    'FR-COR': 90},
#   'fossilFreePercentage': 48,
#   'renewablePercentage': 41,
#   'powerConsumptionTotal': 40043,
#   'powerProductionTotal': 33263,
#   'powerImportTotal': 6908,
#   'powerExportTotal': 129,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T09:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T08:26:27.529Z',
#   'powerConsumptionBreakdown': {'nuclear': 2544,
#    'geothermal': 596,
#    'biomass': 755,
#    'coal': 813,
#    'wind': 1964,
#    'solar': 8860,
#    'hydro': 4023,
#    'gas': 16795,
#    'oil': 39,
#    'unknown': 2878,
#    'hydro discharge': 308,
#    'battery discharge': 38},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 596,
#    'biomass': 697,
#    'coal': 718,
#    'wind': 1311,
#    'solar': 8332,
#    'hydro': 2829,
#    'gas': 16535,
#    'oil': 12,
#    'unknown': 2821,
#    'hydro discharge': 186,
#    'battery discharge': -162},
#   'powerImportBreakdown': {'AT': 133,
#    'CH': 1823,
#    'FR': 2900,
#    'GR': 499,
#    'MT': 0,
#    'SI': 557,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'MT': 103,
#    'SI': 0,
#    'FR-COR': 71},
#   'fossilFreePercentage': 48,
#   'renewablePercentage': 42,
#   'powerConsumptionTotal': 39612,
#   'powerProductionTotal': 34036,
#   'powerImportTotal': 5912,
#   'powerExportTotal': 173,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T10:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T09:42:04.221Z',
#   'powerConsumptionBreakdown': {'nuclear': 2320,
#    'geothermal': 595,
#    'biomass': 762,
#    'coal': 806,
#    'wind': 1987,
#    'solar': 9479,
#    'hydro': 3731,
#    'gas': 16070,
#    'oil': 41,
#    'unknown': 2759,
#    'hydro discharge': 346,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 595,
#    'biomass': 707,
#    'coal': 719,
#    'wind': 1404,
#    'solar': 8898,
#    'hydro': 2715,
#    'gas': 15918,
#    'oil': 12,
#    'unknown': 2721,
#    'hydro discharge': 222,
#    'battery discharge': -341},
#   'powerImportBreakdown': {'AT': 135,
#    'CH': 1518,
#    'FR': 2644,
#    'GR': 448,
#    'MT': 0,
#    'SI': 766,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'MT': 124,
#    'SI': 0,
#    'FR-COR': 61},
#   'fossilFreePercentage': 50,
#   'renewablePercentage': 44,
#   'powerConsumptionTotal': 38896,
#   'powerProductionTotal': 33912,
#   'powerImportTotal': 5510,
#   'powerExportTotal': 184,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T11:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:46.714Z',
#   'createdAt': '2025-11-17T10:26:03.734Z',
#   'powerConsumptionBreakdown': {'nuclear': 2467,
#    'geothermal': 593,
#    'biomass': 746,
#    'coal': 769,
#    'wind': 2092,
#    'solar': 8942,
#    'hydro': 3625,
#    'gas': 15324,
#    'oil': 42,
#    'unknown': 2625,
#    'hydro discharge': 37,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 596,
#    'biomass': 703,
#    'coal': 715,
#    'wind': 1477,
#    'solar': 8540,
#    'hydro': 2609,
#    'gas': 15529,
#    'oil': 12,
#    'unknown': 2635,
#    'hydro discharge': -410,
#    'battery discharge': -845},
#   'powerImportBreakdown': {'AT': 144,
#    'CH': 2038,
#    'FR': 2872,
#    'GR': 463,
#    'MT': 0,
#    'SI': 363,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'MT': 124,
#    'SI': 0,
#    'FR-COR': 53},
#   'fossilFreePercentage': 50,
#   'renewablePercentage': 43,
#   'powerConsumptionTotal': 37262,
#   'powerProductionTotal': 32815,
#   'powerImportTotal': 5879,
#   'powerExportTotal': 177,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T12:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T11:25:09.003Z',
#   'powerConsumptionBreakdown': {'nuclear': 2577,
#    'geothermal': 595,
#    'biomass': 735,
#    'coal': 709,
#    'wind': 2165,
#    'solar': 8022,
#    'hydro': 3667,
#    'gas': 16008,
#    'oil': 39,
#    'unknown': 2727,
#    'hydro discharge': 44,
#    'battery discharge': 0},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 595,
#    'biomass': 699,
#    'coal': 713,
#    'wind': 1525,
#    'solar': 7651,
#    'hydro': 2617,
#    'gas': 16005,
#    'oil': 12,
#    'unknown': 2681,
#    'hydro discharge': -365,
#    'battery discharge': -342},
#   'powerImportBreakdown': {'AT': 148,
#    'CH': 2042,
#    'FR': 2982,
#    'GR': 496,
#    'MT': 0,
#    'SI': 46,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'MT': 143,
#    'SI': 0,
#    'FR-COR': 72},
#   'fossilFreePercentage': 48,
#   'renewablePercentage': 41,
#   'powerConsumptionTotal': 37289,
#   'powerProductionTotal': 32497,
#   'powerImportTotal': 5714,
#   'powerExportTotal': 215,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T13:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T12:40:38.358Z',
#   'powerConsumptionBreakdown': {'nuclear': 2635,
#    'geothermal': 586,
#    'biomass': 500,
#    'coal': 722,
#    'wind': 1049,
#    'solar': 4710,
#    'hydro': 4272,
#    'gas': 17751,
#    'oil': 35,
#    'unknown': 2729,
#    'hydro discharge': 285,
#    'battery discharge': 378},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 593,
#    'biomass': 450,
#    'coal': 725,
#    'wind': 340,
#    'solar': 4403,
#    'hydro': 3229,
#    'gas': 17548,
#    'oil': 10,
#    'unknown': 2698,
#    'hydro discharge': -23,
#    'battery discharge': 179},
#   'powerImportBreakdown': {'AT': 133,
#    'CH': 1991,
#    'FR': 3038,
#    'GR': 499,
#    'MT': 0,
#    'SI': 0,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'MT': 57,
#    'SI': 1,
#    'FR-COR': 99},
#   'fossilFreePercentage': 41,
#   'renewablePercentage': 33,
#   'powerConsumptionTotal': 35654,
#   'powerProductionTotal': 30173,
#   'powerImportTotal': 5690,
#   'powerExportTotal': 186,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T14:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T13:41:28.310Z',
#   'powerConsumptionBreakdown': {'nuclear': 3188,
#    'geothermal': 581,
#    'biomass': 499,
#    'coal': 745,
#    'wind': 1136,
#    'solar': 2228,
#    'hydro': 5329,
#    'gas': 18728,
#    'oil': 42,
#    'unknown': 2789,
#    'hydro discharge': 647,
#    'battery discharge': 428},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 587,
#    'biomass': 436,
#    'coal': 742,
#    'wind': 465,
#    'solar': 1999,
#    'hydro': 3686,
#    'gas': 18511,
#    'oil': 10,
#    'unknown': 2702,
#    'hydro discharge': 459,
#    'battery discharge': 379},
#   'powerImportBreakdown': {'AT': 150,
#    'CH': 2720,
#    'FR': 3340,
#    'GR': 99,
#    'MT': 0,
#    'SI': 195,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 0,
#    'MT': 43,
#    'SI': 0,
#    'FR-COR': 96},
#   'fossilFreePercentage': 39,
#   'renewablePercentage': 30,
#   'powerConsumptionTotal': 36340,
#   'powerProductionTotal': 29975,
#   'powerImportTotal': 6504,
#   'powerExportTotal': 138,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T15:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T14:26:36.710Z',
#   'powerConsumptionBreakdown': {'nuclear': 3507,
#    'geothermal': 586,
#    'biomass': 494,
#    'coal': 774,
#    'wind': 1180,
#    'solar': 457,
#    'hydro': 6390,
#    'gas': 18844,
#    'oil': 50,
#    'unknown': 2919,
#    'hydro discharge': 1002,
#    'battery discharge': 785},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 589,
#    'biomass': 437,
#    'coal': 746,
#    'wind': 496,
#    'solar': 330,
#    'hydro': 4232,
#    'gas': 18903,
#    'oil': 10,
#    'unknown': 2794,
#    'hydro discharge': 814,
#    'battery discharge': 827},
#   'powerImportBreakdown': {'AT': 137,
#    'CH': 3244,
#    'FR': 3489,
#    'GR': 0,
#    'ME': 1,
#    'MT': 0,
#    'SI': 371,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 286,
#    'ME': 0,
#    'MT': 49,
#    'SI': 0,
#    'FR-COR': 97},
#   'fossilFreePercentage': 39,
#   'renewablePercentage': 30,
#   'powerConsumptionTotal': 36986,
#   'powerProductionTotal': 30177,
#   'powerImportTotal': 7241,
#   'powerExportTotal': 432,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T16:00:00.000Z',
#   'updatedAt': '2025-11-19T18:55:06.597Z',
#   'createdAt': '2025-11-17T15:39:59.781Z',
#   'powerConsumptionBreakdown': {'nuclear': 3367,
#    'geothermal': 613,
#    'biomass': 735,
#    'coal': 808,
#    'wind': 1397,
#    'solar': 106,
#    'hydro': 6406,
#    'gas': 22070,
#    'oil': 93,
#    'unknown': 3040,
#    'hydro discharge': 1183,
#    'battery discharge': 1190},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 614,
#    'biomass': 685,
#    'coal': 753,
#    'wind': 696,
#    'solar': 74,
#    'hydro': 4238,
#    'gas': 22065,
#    'oil': 52,
#    'unknown': 2919,
#    'hydro discharge': 937,
#    'battery discharge': 1247},
#   'powerImportBreakdown': {'AT': 130,
#    'CH': 2860,
#    'FR': 3573,
#    'GR': 0,
#    'ME': 1,
#    'MT': 0,
#    'SI': 631,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 286,
#    'ME': 0,
#    'MT': 70,
#    'SI': 0,
#    'FR-COR': 107},
#   'fossilFreePercentage': 37,
#   'renewablePercentage': 29,
#   'powerConsumptionTotal': 41008,
#   'powerProductionTotal': 34277,
#   'powerImportTotal': 7194,
#   'powerExportTotal': 463,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T17:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T16:41:10.459Z',
#   'powerConsumptionBreakdown': {'nuclear': 3634,
#    'geothermal': 614,
#    'biomass': 702,
#    'coal': 866,
#    'wind': 1547,
#    'solar': 8,
#    'hydro': 6542,
#    'gas': 22260,
#    'oil': 87,
#    'unknown': 2973,
#    'hydro discharge': 1097,
#    'battery discharge': 968},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 614,
#    'biomass': 628,
#    'coal': 752,
#    'wind': 710,
#    'solar': 0,
#    'hydro': 4028,
#    'gas': 22190,
#    'oil': 52,
#    'unknown': 2838,
#    'hydro discharge': 731,
#    'battery discharge': 963},
#   'powerImportBreakdown': {'AT': 160,
#    'CH': 3435,
#    'FR': 3846,
#    'GR': 0,
#    'ME': 1,
#    'MT': 0,
#    'SI': 807,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 257,
#    'ME': 0,
#    'MT': 77,
#    'SI': 0,
#    'FR-COR': 125},
#   'fossilFreePercentage': 37,
#   'renewablePercentage': 28,
#   'powerConsumptionTotal': 41297,
#   'powerProductionTotal': 33506,
#   'powerImportTotal': 8249,
#   'powerExportTotal': 458,
#   'isEstimated': False,
#   'estimationMethod': None},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T18:00:00.000Z',
#   'updatedAt': '2025-11-19T18:41:36.542Z',
#   'createdAt': '2025-11-17T17:26:25.905Z',
#   'powerConsumptionBreakdown': {'nuclear': 3532,
#    'geothermal': 610,
#    'biomass': 722,
#    'coal': 835,
#    'wind': 1503,
#    'solar': 0,
#    'hydro': 5959,
#    'gas': 22141,
#    'oil': 92,
#    'unknown': 3027,
#    'hydro discharge': 1215,
#    'battery discharge': 829},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 613,
#    'biomass': 662,
#    'coal': 772,
#    'wind': 720,
#    'solar': 0,
#    'hydro': 3631,
#    'gas': 22154,
#    'oil': 52,
#    'unknown': 2906,
#    'hydro discharge': 744,
#    'battery discharge': 875},
#   'powerImportBreakdown': {'AT': 132,
#    'CH': 3192,
#    'FR': 3738,
#    'GR': 0,
#    'ME': 53,
#    'MT': 0,
#    'SI': 632,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 255,
#    'ME': 0,
#    'MT': 53,
#    'SI': 0,
#    'FR-COR': 104},
#   'fossilFreePercentage': 36,
#   'renewablePercentage': 27,
#   'powerConsumptionTotal': 40465,
#   'powerProductionTotal': 33129,
#   'powerImportTotal': 7747,
#   'powerExportTotal': 412,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'},
#  {'zone': 'IT',
#   'datetime': '2025-11-19T19:00:00.000Z',
#   'updatedAt': '2025-11-19T18:26:20.500Z',
#   'createdAt': '2025-11-17T18:41:16.423Z',
#   'powerConsumptionBreakdown': {'nuclear': 3587,
#    'geothermal': 609,
#    'biomass': 733,
#    'coal': 852,
#    'wind': 1566,
#    'solar': 0,
#    'hydro': 5243,
#    'gas': 21584,
#    'oil': 91,
#    'unknown': 2877,
#    'hydro discharge': 1069,
#    'battery discharge': 638},
#   'powerProductionBreakdown': {'nuclear': None,
#    'geothermal': 613,
#    'biomass': 664,
#    'coal': 770,
#    'wind': 722,
#    'solar': 0,
#    'hydro': 3179,
#    'gas': 21611,
#    'oil': 52,
#    'unknown': 2776,
#    'hydro discharge': 537,
#    'battery discharge': 669},
#   'powerImportBreakdown': {'AT': 128,
#    'CH': 3028,
#    'FR': 3710,
#    'GR': 0,
#    'ME': 117,
#    'MT': 0,
#    'SI': 625,
#    'FR-COR': 0},
#   'powerExportBreakdown': {'AT': 0,
#    'CH': 0,
#    'FR': 0,
#    'GR': 197,
#    'ME': 0,
#    'MT': 60,
#    'SI': 0,
#    'FR-COR': 97},
#   'fossilFreePercentage': 35,
#   'renewablePercentage': 26,
#   'powerConsumptionTotal': 38849,
#   'powerProductionTotal': 31594,
#   'powerImportTotal': 7609,
#   'powerExportTotal': 353,
#   'isEstimated': True,
#   'estimationMethod': 'TIME_SLICER_AVERAGE'}]

# %%
import pandas as pd

# create separated dataframes to store variables with multiple fields

selected = ['powerConsumptionBreakdown', 'powerProductionBreakdown', 'powerImportBreakdown', 'powerExportBreakdown']
powerConsumptionBreakdown_df = pd.DataFrame(columns=['nuclear','geothermal','biomass','coal','wind','solar','hydro','gas','oil','unknown','hydro discharge','battery discharge'])
powerProductionBreakdown_df = pd.DataFrame(columns=['nuclear','geothermal','biomass','coal','wind','solar','hydro','gas','oil','unknown','hydro discharge','battery discharge'])
powerImportBreakdown_df = pd.DataFrame(columns=['AT','CH','FR','GR','ME','MT','SI','FR-COR'])
powerExportBreakdown_df = pd.DataFrame(columns=['AT','CH','FR','GR','ME','MT','SI','FR-COR'])
date_strings = list()

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

for i, time_step in enumerate(hystorical_data):
    powerConsumptionBreakdown_df.loc[i] = time_step['powerConsumptionBreakdown']
    powerProductionBreakdown_df.loc[i] = time_step['powerProductionBreakdown']
    powerImportBreakdown_df.loc[i] = time_step['powerImportBreakdown']
    powerExportBreakdown_df.loc[i] = time_step['powerExportBreakdown']
    date_strings.append(time_step['datetime'])

# Convert strings to datetime objects
date_time = [
    datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%S.%fZ") for date_str in date_strings
]
powerConsumptionBreakdown_df
# Out:
#     nuclear  geothermal  biomass  coal  wind  solar  hydro    gas  oil  \
# 0      3097         610      768   935  2409      2   4322  17068   59
# 1      2966         598      782  1060  2605      1   4112  14584   58
# 2      3034         612      821  1116  2987      1   3997  12298   51
# 3      2696         606      625   978  2094      1   3470  11521   41
# 4      2785         614      746   921  2840      1   3487  10532   47
# 5      2740         610      718   877  2790      1   3343   9961   43
# 6      2742         610      727   842  2767      1   3217  10044   42
# 7      2738         612      747   874  2734      1   3330  10766   32
# 8      2498         615      738   879  2556      8   3473  12961   40
# 9      2557         615      727   764  2441    119   3751  16379   41
# 10     2921         604      730   812  2245    966   5416  17866   38
# 11     2994         598      739   839  2189   3579   5775  17740   38
# 12     2965         597      752   858  2238   6918   4985  17098   38
# 13     2544         596      755   813  1964   8860   4023  16795   39
# 14     2320         595      762   806  1987   9479   3731  16070   41
# 15     2467         593      746   769  2092   8942   3625  15324   42
# 16     2577         595      735   709  2165   8022   3667  16008   39
# 17     2635         586      500   722  1049   4710   4272  17751   35
# 18     3188         581      499   745  1136   2228   5329  18728   42
# 19     3507         586      494   774  1180    457   6390  18844   50
# 20     3367         613      735   808  1397    106   6406  22070   93
# 21     3634         614      702   866  1547      8   6542  22260   87
# 22     3532         610      722   835  1503      0   5959  22141   92
# 23     3587         609      733   852  1566      0   5243  21584   91
#
#     unknown  hydro discharge  battery discharge
# 0      2518              205                  4
# 1      2258              128                  1
# 2      2015               87                  1
# 3      1775               58                  0
# 4      1739               24                  0
# 5      1684               17                  0
# 6      1806               17                  0
# 7      1903               18                  0
# 8      2082              107                  1
# 9      2575              109                 50
# 10     2878              389                399
# 11     2917             1097                343
# 12     2930              294                369
# 13     2878              308                 38
# 14     2759              346                  0
# 15     2625               37                  0
# 16     2727               44                  0
# 17     2729              285                378
# 18     2789              647                428
# 19     2919             1002                785
# 20     3040             1183               1190
# 21     2973             1097                968
# 22     3027             1215                829
# 23     2877             1069                638

# %%
powerProductionBreakdown_df
# Out:
#    nuclear  geothermal  biomass  coal  wind  solar  hydro    gas  oil  \
# 0     None         610      685   792  1792      0   2739  16754   11
# 1     None         598      691   865  1898      0   2479  14157   11
# 2     None         612      722   877  2218      0   2267  11923   11
# 3     None         615      559   803  1361      0   2262  11521   12
# 4     None         615      675   713  2091      0   2222  10374   12
# 5     None         615      668   710  2074      0   2148  10067   12
# 6     None         615      683   710  2033      0   2041  10199   12
# 7     None         615      691   670  1949      0   2077  10795   12
# 8     None         615      679   670  1830      0   2327  12778   12
# 9     None         614      671   684  1791    107   2717  16181   12
# 10    None         603      674   761  1553    916   3879  17552   12
# 11    None         598      674   754  1473   3410   4015  17370   12
# 12    None         597      683   741  1517   6486   3287  16691   12
# 13    None         596      697   718  1311   8332   2829  16535   12
# 14    None         595      707   719  1404   8898   2715  15918   12
# 15    None         596      703   715  1477   8540   2609  15529   12
# 16    None         595      699   713  1525   7651   2617  16005   12
# 17    None         593      450   725   340   4403   3229  17548   10
# 18    None         587      436   742   465   1999   3686  18511   10
# 19    None         589      437   746   496    330   4232  18903   10
# 20    None         614      685   753   696     74   4238  22065   52
# 21    None         614      628   752   710      0   4028  22190   52
# 22    None         613      662   772   720      0   3631  22154   52
# 23    None         613      664   770   722      0   3179  21611   52
#
#     unknown  hydro discharge  battery discharge
# 0      2474               24                -36
# 1      2214               -5                -35
# 2      1979               -6               -247
# 3      1821             -347               -687
# 4      1741             -429               -344
# 5      1716             -392               -947
# 6      1848             -342              -1022
# 7      1933             -525               -560
# 8      2072              -51               -252
# 9      2518              -43                 31
# 10     2777              170                432
# 11     2813              801                354
# 12     2835               57                357
# 13     2821              186               -162
# 14     2721              222               -341
# 15     2635             -410               -845
# 16     2681             -365               -342
# 17     2698              -23                179
# 18     2702              459                379
# 19     2794              814                827
# 20     2919              937               1247
# 21     2838              731                963
# 22     2906              744                875
# 23     2776              537                669

# %% [markdown]
# Visualize the results

# %%
def stacked_bar_chart(df, title):

    plt.figure(figsize=(14, 8))
    num_hours = len(df)

    # Plot a stacked bar chart for all columns
    bottom = 0
    for column in df.columns:
        # NB: not all the values are always present therefore a try\except block is needed
        try:
            plt.bar(range(num_hours), df[column], label=column, bottom=bottom)
            bottom += df[column]
        except:
            continue

    plt.xlabel('Hour')
    plt.ylabel('Power (MW)')
    plt.title(title)
    plt.legend()
    plt.show()

stacked_bar_chart(powerConsumptionBreakdown_df, 'Power consumption Breakdown')
stacked_bar_chart(powerProductionBreakdown_df, 'Power production Breakdown')
stacked_bar_chart(powerImportBreakdown_df, 'Power import Breakdown')
stacked_bar_chart(powerExportBreakdown_df, 'Power export Breakdown')

# %% [markdown]
# Now choose and endpoint of your choice, explore the data available and visualize it in a proper way.

# %% [markdown]
# # Part VI: Home Assignement - Exploring APIs with RapidAPI

# %% [markdown]
# **Instructions:**
# Visit the [RapidAPI Hub](https://rapidapi.com/hub) and select a free API of your choice to experiment with. Dive into the available endpoints, explore their functionalities, and familiarize yourself with the data they provide. Have fun and get creative! 🎉
#
# This exercise is part of the final evaluation for the course and serves as the first step in a larger project. In the next lab session, we will build upon this work using data visualization tools and concepts introduced during class.
#
# **For now:**
# 1. Choose an API and start exploring its features.
# 2. Understand the structure of the data you can retrieve.
# 3. Identify the key information you’d like to extract for visualization in the future.
#
# Stay tuned for more detailed instructions in the next lab session for **Home Assignment I**.
